# %% [markdown]
# # Mount Google drive

# %% [markdown]
# need to run the below cell to mount the drive with notebook (also for testing the model)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Import Libraries

# %% [markdown]
# need to run the below cell to train or test the model **(both locally and for huggingface)**

# %%
# !pip install datasets
# !pip install sacremoses
# !pip install transformers
# !pip install huggingface_hub
# !pip install transformers[sentencepiece] datasets

# %% [markdown]
# need to run the below cell to train or test the model **(only for huggingface)**

# %%
from huggingface_hub import notebook_login

notebook_login()
# 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          ------------------(use this token in the box below)-------------------

# %% [markdown]
# need to run the below cell to train or test the model **(only for huggingface)**

# %%
# !apt install git-lfs
# !git config --global user.email "shamimmahbub230@gmail.com"
# !git config --global user.name "shamim237"

# %% [markdown]
# # Data Preprocessing
# ### ***Not required to run this section for testing the model***

# %% [markdown]
# Load dataset

# %%
import pandas as pd
import numpy as np
from datasets import Dataset

# %%
# path of tsv file
tsv_file= "/content/drive/MyDrive/Language-Translation/Sentence pairs in English-Spanish - 2022-10-18_cleaned.tsv"
 
# reading given tsv file
csv = pd.read_table(tsv_file,sep='\t', encoding= "utf-8")
 
# converting tsv file into csv
csv.to_csv('/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en.csv',index=False)

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en.csv')

# %%
# set column names
dataset.columns = ['english', 'spanish']

# %%
dataset

# %%
# remove duplicates values from each column
dataset = dataset.drop_duplicates()

# %%
dataset # dataset after removing duplicates pairs

# %%
# Shuffle the dataset
dataset = dataset.sample(frac=1, random_state=0)
dataset.iloc[1000:1010]

# %%
# # splitting dataframe by row index
# train = dataset.iloc[:225000]
# validation = dataset.iloc[225000:240000]
# test = dataset.iloc[240000:253638]

train, validation, test = np.split(dataset.sample(frac=1, random_state=42), [int(.9*len(dataset)), int(.95*len(dataset))])

# %%
train

# %%
validation

# %%
test
# Out:
#                                                   english  \
# 238691                    I don't pick out their clothes.
# 188615  There must've been a tacit understanding betwe...
# 58380                                      I do not work.
# 145665    I am wearing an orange t shirt and green pants.
# 206782                          Oh, just the usual stuff.
# ...                                                   ...
# 162328                              Who invented karaoke?
# 236830                      The airbags failed to deploy.
# 88052                Tom has never heard Mary tell a lie.
# 185720                      The devil takes the hindmost.
# 125324                                 Go away. I'm busy.
#
#                                                   spanish
# 238691                      No escojo la ropa para ellos.
# 188615  Tiene que haber existido un acuerdo tácito ent...
# 58380                                         No trabajo.
# 145665  Estoy usando una remera anaranjada y un pantal...
# 206782                        Ah, todo está como siempre.
# ...                                                   ...
# 162328                         ¿Quién inventó el karaoke?
# 236830                           No saltaron los airbags.
# 88052         Tom nunca ha oído a Mary decir una mentira.
# 185720                 El último mono es el que se ahoga.
# 125324                            Lárgate. Estoy ocupada.
#
# [12682 rows x 2 columns]

# %%
# save train and test data for furthur use
train.to_csv('/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en-train.csv', index=False)
validation.to_csv('/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en-valid.csv', index=False)
test.to_csv('/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en-test.csv',index=False)

# %%
# make Dataset Dict
train_ds = Dataset.from_pandas(train,preserve_index = False)
valid_ds = Dataset.from_pandas(validation,preserve_index = False)
test_ds = Dataset.from_pandas(test,preserve_index = False)

# %% [markdown]
# #  Load and Build Model
# ### ***Not required to run this section for testing the model***

# %%
# Checkpoint name of the pre-trained model
model_checkpoint = "Helsinki-NLP/opus-mt-es-en"

# %%
# load tokenizer from transformers to tokenize sentences
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
# set source_language and target_language tokenizer
if "mbart" in model_checkpoint:
    tokenizer.src_lang = "es-XX"
    tokenizer.tgt_lang = "en_XX"

# %%
if model_checkpoint in ["t5-small", "t5-base", "t5-larg", "t5-3b", "t5-11b"]:
    prefix = "translate Spanish to English: "
else:
    prefix = ""

# %%
max_input_length = 128 # max length of input sentence
max_target_length = 128 # max length of output sentence
source_lang = "es"
target_lang = "en"

# define a function for processing the inputs for the model
def preprocess_function(examples):
    inputs = [prefix + ex for ex in examples["spanish"]]
    targets = [ex for ex in examples["english"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
# apply the function on train and validation dataset
train_data = train_ds.map(preprocess_function, batched=True)
valid_data = valid_ds.map(preprocess_function, batched=True)
test_data = test_ds.map(preprocess_function, batched=True)

# %%
# download and load the pre-trained model
from transformers import TFAutoModelForSeq2SeqLM, DataCollatorForSeq2Seq
model = TFAutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)

# %%
# hyperparameters
batch_size = 32
learning_rate = 2e-5
weight_decay = 0.01

model_name = model_checkpoint.split("/")[-1]
# push_to_hub_model_id = f"{model_name}-finetune101-{source_lang}-to-{target_lang}"

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors="tf")
generation_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors="tf", pad_to_multiple_of=128)

# %%
train_dataset = model.prepare_tf_dataset(
    train_data,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=data_collator,
)

validation_dataset = model.prepare_tf_dataset(
    valid_data,
    batch_size=batch_size,
    shuffle=False,
    collate_fn=data_collator,
)

test_dataset = model.prepare_tf_dataset(
    test_data,
    batch_size= 4,
    shuffle = False,
    collate_fn = data_collator,
)

# %%
# compile the model
from transformers import AdamWeightDecay
import tensorflow as tf

optimizer = AdamWeightDecay(learning_rate=learning_rate, weight_decay_rate=weight_decay)
model.compile(optimizer=optimizer, metrics=['acc'])

# %%
# early stopping callback to avoid unwanted training
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience= 5,
    verbose= 0,
    mode= "auto",
    baseline=None,
    restore_best_weights=False)

# save the best weights of the model while training
best_model = tf.keras.callbacks.ModelCheckpoint(
    '/content/drive/MyDrive/Language-Translation/es-en/models/model-{epoch:03d}-{acc:03f}-{val_acc:03f}.h5', 
    verbose=1, 
    monitor='val_loss',
    save_weights_only=True, 
    save_best_only=True,
    mode='auto')

# %%
from transformers.keras_callbacks import PushToHubCallback
from tensorflow.keras.callbacks import TensorBoard

tensorboard_callback = TensorBoard(log_dir="./translation_model_save/logs")
callbacks = [early_stop, best_model, tensorboard_callback]

# start to train the model
model.fit(train_dataset, validation_data=validation_dataset, epochs= 50, callbacks=callbacks)
# Out:
# Epoch 1/50
# 7133/7133 [==============================] - ETA: 0s - loss: 0.5028 - acc: 0.3416
# Epoch 1: val_loss improved from inf to 0.45749, saving model to /content/drive/MyDrive/Language-Translation/es-en/models/model-001-0.341647-0.340052.h5
# 7133/7133 [==============================] - 829s 112ms/step - loss: 0.5028 - acc: 0.3416 - val_loss: 0.4575 - val_acc: 0.3401
# Epoch 2/50
# 7133/7133 [==============================] - ETA: 0s - loss: 0.4209 - acc: 0.3483
# Epoch 2: val_loss improved from 0.45749 to 0.45176, saving model to /content/drive/MyDrive/Language-Translation/es-en/models/model-002-0.348263-0.340911.h5
# 7133/7133 [==============================] - 799s 112ms/step - loss: 0.4209 - acc: 0.3483 - val_loss: 0.4518 - val_acc: 0.3409
# Epoch 3/50
# 7133/7133 [==============================] - ETA: 0s - loss: 0.3689 - acc: 0.3519
# Epoch 3: val_loss did not improve from 0.45176
# 7133/7133 [==============================] - 793s 111ms/step - loss: 0.3689 - acc: 0.3519 - val_loss: 0.4544 - val_acc: 0.3410
# Epoch 4/50
# 7133/7133 [==============================] - ETA: 0s - loss: 0.3269 - acc: 0.3535
# Epoch 4: val_loss did not improve from 0.45176
# 7133/7133 [==============================] - 798s 112ms/step - loss: 0.3269 - acc: 0.3535 - val_loss: 0.4618 - val_acc: 0.3410
# Epoch 5/50
# 7133/7133 [==============================] - ETA: 0s - loss: 0.2914 - acc: 0.3579
# Epoch 5: val_loss did not improve from 0.45176
# 7133/7133 [==============================] - 795s 111ms/step - loss: 0.2914 - acc: 0.3579 - val_loss: 0.4712 - val_acc: 0.3412
# Epoch 6/50
# 7133/7133 [==============================] - ETA: 0s - loss: 0.2611 - acc: 0.3598
# Epoch 6: val_loss did not improve from 0.45176
# 7133/7133 [==============================] - 796s 112ms/step - loss: 0.2611 - acc: 0.3598 - val_loss: 0.4824 - val_acc: 0.3411
# Epoch 7/50
# 7133/7133 [==============================] - ETA: 0s - loss: 0.2348 - acc: 0.3632
# Epoch 7: val_loss did not improve from 0.45176
# 7133/7133 [==============================] - 795s 111ms/step - loss: 0.2348 - acc: 0.3632 - val_loss: 0.4936 - val_acc: 0.3406

# %% [markdown]
# # Save and Load trained Model

# %%
# save trained tokenizer and model for testing purspose (save to local drive)
tokenizer.save_pretrained("/content/drive/MyDrive/Language-Translation/es-en/misc")
model.save_pretrained("/content/drive/MyDrive/Language-Translation/es-en/misc")

# %%
# push the model to huggingface to save it for later use (save to huggingface)
model.push_to_hub("shamim237/es-en-model")
tokenizer.push_to_hub("shamim237/es-en-model")

# %% [markdown]
# run the below cell to load the model for testing **(only for huggingface)**

# %%
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM

# load the saved model and tokenizer from huggingface

model_name = 'shamim237/es-en-model'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = TFAutoModelForSeq2SeqLM.from_pretrained(model_name)

# %% [markdown]
# run the below cell to load the model for testing **(only for locally)**

# %%
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM

# load the saved model and tokenizer from local drive

tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/Language-Translation/es-en/misc")
model = TFAutoModelForSeq2SeqLM.from_pretrained("/content/drive/MyDrive/Language-Translation/es-en/misc")

# %% [markdown]
# run the cell, if you want to see the test accuracy and loss of the model on testing dataset

# %%
model.compile(optimizer=optimizer, metrics=['acc'])
model.evaluate(test_dataset)
# Out:
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! To disable this behaviour please pass a loss argument, or explicitly pass `loss=None` if you do not want your model to compute a loss.
# 3171/3171 [==============================] - 157s 46ms/step - loss: 0.4724 - acc: 0.6049
# [0.4723685383796692, 0.6049464344978333]

# %% [markdown]
# # Inference of the trained Model

# %% [markdown]
# run all the cells in the below, to test the model in training and testing dataset **(both locally and for huggingface)**

# %%
import time
import nltk
import pandas as pd
import tensorflow as tf
from collections import Counter
from nltk.util import everygrams, ngrams
nltk.download('punkt')

# %%
@tf.function(jit_compile=True)
def generate(inputs):
    return model.generate(**inputs, max_length=128)

# %%
def sentence_gleu(references, hypothesis, min_len=1, max_len=4):
    return corpus_gleu([references], [hypothesis], min_len=min_len, max_len=max_len)


def corpus_gleu(list_of_references, hypotheses, min_len=1, max_len=4):

    # sanity check
    assert len(list_of_references) == len(
        hypotheses
    ), "The number of hypotheses and their reference(s) should be the same"

    # sum matches and max-token-lengths over all sentences
    corpus_n_match = 0
    corpus_n_all = 0

    for references, hypothesis in zip(list_of_references, hypotheses):
        hyp_ngrams = Counter(everygrams(hypothesis, min_len, max_len))
        tpfp = sum(hyp_ngrams.values())  # True positives + False positives.

        hyp_counts = []
        for reference in references:
            ref_ngrams = Counter(everygrams(reference, min_len, max_len))
            # True positives + False negatives.
            tpfn = sum(ref_ngrams.values())

            overlap_ngrams = ref_ngrams & hyp_ngrams
            tp = sum(overlap_ngrams.values())  # True positives.
            n_all = max(tpfp, tpfn)

            if n_all > 0:
                hyp_counts.append((tp, n_all))

        # use the reference yielding the highest score
        if hyp_counts:
            n_match, n_all = max(hyp_counts, key=lambda hc: hc[0] / hc[1])
            corpus_n_match += n_match
            corpus_n_all += n_all

    # corner case: empty corpus or empty references---don't divide by zero!
    if corpus_n_all == 0:
        gleu_score = 0.0
    else:
        gleu_score = corpus_n_match / corpus_n_all

    return gleu_score

# %% [markdown]
# get individual GBLEU score on test dataset

# %%
test_data = pd.read_csv("/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en-test.csv")

# %%
start_time = time.time()
sco = []
k = 0
for eng, spa in zip(test_data['spanish'], test_data['english']):
  k +=1
  print(k)
  print("Spanish           : ", eng)
  print("Actual English    : ", spa)
  tokenized_data = tokenizer([eng], return_tensors="np", pad_to_multiple_of=128)
  #print(tokenized_data)
  out = generate(tokenized_data)
  with tokenizer.as_target_tokenizer():
    print("Predicted English : ", tokenizer.decode(out[0], skip_special_tokens=True))
    actual_spanish    = nltk.word_tokenize(spa)
    predicted_spanish = nltk.word_tokenize(tokenizer.decode(out[0], skip_special_tokens=True)) 
    scores = corpus_gleu([[actual_spanish]], [predicted_spanish], min_len=1, max_len=128)
    print("GLEU Score        : ", scores)
    sco.append(scores)
    if k ==500:
      now = time.time()
      t_time = now-start_time
      print(t_time)
      break
# Out:
# 1
# Spanish           :  No escojo la ropa para ellos.
# Actual English    :  I don't pick out their clothes.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3547: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   "`as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your "
# Predicted English :  I don't choose clothes for them.
# GLEU Score        :  0.2222222222222222
# 2
# Spanish           :  Tiene que haber existido un acuerdo tácito entre ellos.
# Actual English    :  There must've been a tacit understanding between them.
# Predicted English :  There must've been a tacit agreement between them.
# GLEU Score        :  0.4909090909090909
# 3
# Spanish           :  No trabajo.
# Actual English    :  I do not work.
# Predicted English :  I don't work.
# GLEU Score        :  0.4
# 4
# Spanish           :  Estoy usando una remera anaranjada y un pantalón verde.
# Actual English    :  I am wearing an orange t shirt and green pants.
# Predicted English :  I'm wearing an orange t shirt and green pants.
# GLEU Score        :  0.696969696969697
# 5
# Spanish           :  Ah, todo está como siempre.
# Actual English    :  Oh, just the usual stuff.
# WARNING:tensorflow:5 out of the last 5 calls to <function generate at 0x7f8c16838e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicted English :  Ah, everything is as usual.
# GLEU Score        :  0.10714285714285714
# 6
# Spanish           :  No me agrada Tom y no confío en él.
# Actual English    :  I don't like Tom and I don't trust him.
# WARNING:tensorflow:6 out of the last 6 calls to <function generate at 0x7f8c16838e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicted English :  I don't like Tom and I don't trust him.
# GLEU Score        :  1.0
# 7
# Spanish           :  No tengo nada que ver con el asunto.
# Actual English    :  I have nothing to do with the affair.
# Predicted English :  I have nothing to do with the affair.
# GLEU Score        :  1.0
# 8
# Spanish           :  Él no es el tipo de persona al que le gusta escuchar jazz.
# Actual English    :  He is not the sort of person who likes to listen to jazz.
# Predicted English :  He isn't the type of person who likes to listen to jazz.
# GLEU Score        :  0.4666666666666667
# 9
# Spanish           :  Ni pensar en salir en esta lluvia.
# Actual English    :  Going out in this rain is out of the question.
# Predicted English :  Don't even think about going out in this rain.
# GLEU Score        :  0.16666666666666666
# 10
# Spanish           :  Ella es gentil.
# Actual English    :  She is kind.
# Predicted English :  She is kind.
# GLEU Score        :  1.0
# 11
# Spanish           :  No sabía cuánto tiempo había estado el pollo sobrante en el frigorífico, así que lo tiré.
# Actual English    :  I didn't know how long the leftover chicken had been in the refrigerator, so threw it away.
# Predicted English :  I didn't know how long the leftover chicken had been in the refrigerator, so I threw it away.
# GLEU Score        :  0.6320346320346321
# 12
# Spanish           :  Pagué 200 $ en impuestos.
# Actual English    :  I paid $200 in taxes.
# Predicted English :  I paid $200 in taxes.
# GLEU Score        :  1.0
# 13
# Spanish           :  Fue la primera delegación que el nuevo país hubiese recibido alguna vez.
# Actual English    :  It was the first delegation that the new country had ever received.
# Predicted English :  It was the first delegation the new country had ever received.
# GLEU Score        :  0.4725274725274725
# 14
# Spanish           :  ¿Bajás?
# Actual English    :  Are you going down?
# Predicted English :  Are you going down?
# GLEU Score        :  1.0
# 15
# Spanish           :  No voy a salir porque tengo que limpiar la casa.
# Actual English    :  I am not going out because I have to clean the house.
# Predicted English :  I'm not going out because I have to clean the house.
# GLEU Score        :  0.7362637362637363
# 16
# Spanish           :  La naturaleza humana es buena y la maldad es esencialmente antinatural.
# Actual English    :  Human nature is good and wickedness is essentially unnatural.
# Predicted English :  Human nature is good and evil is essentially unnatural.
# GLEU Score        :  0.45454545454545453
# 17
# Spanish           :  Estábamos hablando.
# Actual English    :  We were talking.
# Predicted English :  We were talking.
# GLEU Score        :  1.0
# 18
# Spanish           :  Tom cogió el autobús erróneo.
# Actual English    :  Tom took the wrong bus.
# Predicted English :  Tom took the wrong bus.
# GLEU Score        :  1.0
# 19
# Spanish           :  Aún no quiero morir.
# Actual English    :  I don't want to die yet.
# Predicted English :  I don't want to die yet.
# GLEU Score        :  1.0
# 20
# Spanish           :  Gracias por su generosa invitación pero no queremos abusar de su hospitalidad.
# Actual English    :  Thank you for the generous invitation but we don't want to wear out our welcome.
# Predicted English :  Thanks for your generous invitation, but we don't want to abuse your hospitality.
# GLEU Score        :  0.16993464052287582
# 21
# Spanish           :  ¿No puede la música ser descrita como la matemática del sentido, las matemáticas como la música de la razón? El músico siente matemática, el matemático piensa música música el sueño, matemática la vida laboral.
# Actual English    :  May not music be described as the mathematics of the sense, mathematics as music of the reason? The musician feels mathematics, the mathematician thinks music music the dream, mathematics the working life.
# Predicted English :  Can't music be described as meaning mathematics, mathematics as reason music? The musician feels mathematics, the mathematician thinks music the music the dream, mathematics the work life.
# GLEU Score        :  0.14082503556187767
# 22
# Spanish           :  La mejor forma de predecir el futuro es crearlo.
# Actual English    :  The best way to predict the future is to create it.
# Predicted English :  The best way to predict the future is to create it.
# GLEU Score        :  1.0
# 23
# Spanish           :  Estamos desperdiciando tiempo precioso.
# Actual English    :  We're wasting precious time.
# Predicted English :  We're wasting precious time.
# GLEU Score        :  1.0
# 24
# Spanish           :  Thomas abraza a María.
# Actual English    :  Thomas hugs Maria.
# Predicted English :  Thomas hugs Mary.
# GLEU Score        :  0.4
# 25
# Spanish           :  Ellos odiaban a Tom.
# Actual English    :  They hated Tom.
# Predicted English :  They hated Tom.
# GLEU Score        :  1.0
# 26
# Spanish           :  El doctor dijo No hay nada peor para tu salud que el tabaco.
# Actual English    :  The doctor said, There's nothing worse for your health than tobacco.
# Predicted English :  The doctor said Nothing is worse for your health than smoking.
# GLEU Score        :  0.20952380952380953
# 27
# Spanish           :  Yo soy Tom.
# Actual English    :  I'm Tom.
# Predicted English :  I'm Tom.
# GLEU Score        :  1.0
# 28
# Spanish           :  Ni siquiera su maestro lo entendía.
# Actual English    :  Even his teacher didn't understand him.
# Predicted English :  Even his teacher didn't understand him.
# GLEU Score        :  1.0
# 29
# Spanish           :  ¿Sabes por qué al arrollado primavera le dicen arrollado primavera?
# Actual English    :  Do you know why spring rolls are called spring rolls?
# Predicted English :  Do you know the reason why spring is run over and called spring?
# GLEU Score        :  0.12380952380952381
# 30
# Spanish           :  No sé nada acerca de su pasado.
# Actual English    :  I don't know anything about his past.
# Predicted English :  I know nothing about his past.
# GLEU Score        :  0.26666666666666666
# 31
# Spanish           :  El escritorio parece muy rayado.
# Actual English    :  The desk looks badly scratched.
# Predicted English :  The desk looks very scratchy.
# GLEU Score        :  0.3333333333333333
# 32
# Spanish           :  El rojo, de manera opuesta al verde, es una señal de peligro.
# Actual English    :  Red, as opposed to green, is a sign of danger.
# Predicted English :  Red, as opposed to green, is a signal of danger.
# GLEU Score        :  0.5604395604395604
# 33
# Spanish           :  Eres mucho más alto de lo que solías ser.
# Actual English    :  You're much taller than you used to be.
# Predicted English :  You are much taller than you used to be.
# GLEU Score        :  0.6727272727272727
# 34
# Spanish           :  No estaba nada feliz.
# Actual English    :  He was not happy at all.
# Predicted English :  I wasn't at all happy.
# GLEU Score        :  0.21428571428571427
# 35
# Spanish           :  ¿Desde dónde sale el autobús del aeropuerto?
# Actual English    :  Where can I get the airport bus?
# Predicted English :  Where does the airport bus leave from?
# GLEU Score        :  0.2222222222222222
# 36
# Spanish           :  Pídele que cuente por encima su plan.
# Actual English    :  Ask him to sketch out his plan.
# Predicted English :  Ask him to count his plan over.
# GLEU Score        :  0.2777777777777778
# 37
# Spanish           :  Pareces más joven.
# Actual English    :  You look younger.
# Predicted English :  You look younger.
# GLEU Score        :  1.0
# 38
# Spanish           :  La gente dice que la vida es corta.
# Actual English    :  People say that life is short.
# Predicted English :  People say life is short.
# GLEU Score        :  0.4642857142857143
# 39
# Spanish           :  No te engañes.
# Actual English    :  Don't deceive yourself.
# Predicted English :  Don't cheat yourself.
# GLEU Score        :  0.4
# 40
# Spanish           :  Dan te quiere a ti más que a nadie.
# Actual English    :  Dan likes you more than anybody else.
# Predicted English :  Dan loves you more than anyone else.
# GLEU Score        :  0.2777777777777778
# 41
# Spanish           :  Tom dijo que le trazaría un mapa si fuera necesario.
# Actual English    :  Tom said he would draw a map for her if necessary.
# Predicted English :  Tom said he'd draw a map for him if it was necessary.
# GLEU Score        :  0.19047619047619047
# 42
# Spanish           :  Pasamos los fines de semana en nuestra casa de campo.
# Actual English    :  We spend the weekends in our country house.
# Predicted English :  We spent our weekends in our cottage.
# GLEU Score        :  0.17777777777777778
# 43
# Spanish           :  Eso fue absolutamente innecesario.
# Actual English    :  That was absolutely unnecessary.
# Predicted English :  That was absolutely unnecessary.
# GLEU Score        :  1.0
# 44
# Spanish           :  Nancy me contó del incendio.
# Actual English    :  Nancy told me about the fire.
# Predicted English :  Nancy told me about the fire.
# GLEU Score        :  1.0
# 45
# Spanish           :  ¿Saben dónde está?
# Actual English    :  Do you know where he is?
# Predicted English :  Do you know where it is?
# GLEU Score        :  0.4642857142857143
# 46
# Spanish           :  Cuando estaba bailando me dejé llevar y subí a la mesa.
# Actual English    :  I got a bit carried away when I was dancing and got up on the table.
# Predicted English :  When I was dancing, I got carried away and went up to the table.
# GLEU Score        :  0.13071895424836602
# 47
# Spanish           :  Algunos estudiantes la miraron con lágrimas en los ojos.
# Actual English    :  Some students looked at her with tears in their eyes.
# Predicted English :  Some students looked at her with tears in their eyes.
# GLEU Score        :  1.0
# 48
# Spanish           :  Nuestro perro fue atropellado por un camión.
# Actual English    :  Our dog was run over by a truck.
# Predicted English :  Our dog was run over by a truck.
# GLEU Score        :  1.0
# 49
# Spanish           :  Ellos fueron de pesca ayer.
# Actual English    :  They went fishing yesterday.
# Predicted English :  They went fishing yesterday.
# GLEU Score        :  1.0
# 50
# Spanish           :  ¿Cómo llevas las cosas? ¿Todo está bien?
# Actual English    :  How are things with you? Everything all right?
# Predicted English :  How are things with you? Everything all right?
# GLEU Score        :  1.0
# 51
# Spanish           :  Se rompió la computadora.
# Actual English    :  The computer broke.
# Predicted English :  The computer broke.
# GLEU Score        :  1.0
# 52
# Spanish           :  Todo lo que requiere es concentración y soledad.
# Actual English    :  All it takes is concentration and solitude.
# Predicted English :  All that you need is concentration and loneliness.
# GLEU Score        :  0.17777777777777778
# 53
# Spanish           :  El semáforo se puso en rojo.
# Actual English    :  The traffic light changed to red.
# Predicted English :  The traffic light turned red.
# GLEU Score        :  0.32142857142857145
# 54
# Spanish           :  No tienes ni idea de la de veces que he oído decir eso.
# Actual English    :  You have no idea how many times I've heard that.
# Predicted English :  You have no idea how many times I've heard that said.
# GLEU Score        :  0.7362637362637363
# 55
# Spanish           :  Tenemos que decidir nuestro siguiente paso.
# Actual English    :  We have to figure out what we should do next.
# Predicted English :  We have to decide our next step.
# GLEU Score        :  0.12121212121212122
# 56
# Spanish           :  La torre va a colapsar.
# Actual English    :  The tower is going to collapse.
# Predicted English :  The tower is going to collapse.
# GLEU Score        :  1.0
# 57
# Spanish           :  Hay que leer aquellos libros que pueden entenderse fácilmente.
# Actual English    :  Read such books as can be easily understood.
# Predicted English :  One should read those books which can be understood easily.
# GLEU Score        :  0.10606060606060606
# 58
# Spanish           :  Él llevaba un esmoquin.
# Actual English    :  He was wearing a dinner jacket.
# Predicted English :  He was wearing a tuxedo.
# GLEU Score        :  0.39285714285714285
# 59
# Spanish           :  Quiero mejorar mi francés.
# Actual English    :  I want to be better at French.
# Predicted English :  I want to improve my French.
# GLEU Score        :  0.25
# 60
# Spanish           :  El jarrón que rompió es de mi tía.
# Actual English    :  The vase he broke is my aunt's.
# Predicted English :  The vase she broke is my aunt's.
# GLEU Score        :  0.5333333333333333
# 61
# Spanish           :  Claro, yo voy allá con vos.
# Actual English    :  Of course, I will go there with you.
# Predicted English :  Sure, I'll go there with you.
# GLEU Score        :  0.32727272727272727
# 62
# Spanish           :  Ayúdame a elegir.
# Actual English    :  Help me choose.
# Predicted English :  Help me choose.
# GLEU Score        :  1.0
# 63
# Spanish           :  Tiene la misma edad que yo.
# Actual English    :  He is the same age as me.
# Predicted English :  He's the same age as me.
# GLEU Score        :  0.6111111111111112
# 64
# Spanish           :  No te contengas, grita.
# Actual English    :  Don't hold back, shout.
# Predicted English :  Don't hold back, shout.
# GLEU Score        :  1.0
# 65
# Spanish           :  ¿Cuánto tiempo piensas estar aquí?
# Actual English    :  How long do you plan to be here?
# Predicted English :  How long do you intend to stay here?
# GLEU Score        :  0.3111111111111111
# 66
# Spanish           :  Usted arregla.
# Actual English    :  You fix it.
# Predicted English :  You fix it.
# GLEU Score        :  1.0
# 67
# Spanish           :  Tengo treinta años.
# Actual English    :  I'm thirty years old.
# Predicted English :  I am thirty years old.
# GLEU Score        :  0.5238095238095238
# 68
# Spanish           :  Vamos a morir todos.
# Actual English    :  We're all going to die.
# Predicted English :  We're all going to die.
# GLEU Score        :  1.0
# 69
# Spanish           :  Te oigo alto y claro.
# Actual English    :  I can hear you loud and clear.
# Predicted English :  I hear you loud and clear.
# GLEU Score        :  0.6111111111111112
# 70
# Spanish           :  ¿Con qué frecuencia bebe alcohol?
# Actual English    :  How often do you drink alcohol?
# Predicted English :  How often do you drink alcohol?
# GLEU Score        :  1.0
# 71
# Spanish           :  Si no llueve, puedes montar en bicicleta.
# Actual English    :  If it doesn't rain, you can ride your bicycle.
# Predicted English :  If it doesn't rain, you can ride a bicycle.
# GLEU Score        :  0.6153846153846154
# 72
# Spanish           :  Willemstad es la capital de Curazao.
# Actual English    :  Willemstad is the capital of Curaçao.
# Predicted English :  Willemstad is the capital of Curaçao.
# GLEU Score        :  1.0
# 73
# Spanish           :  Badajoz es una ciudad de España.
# Actual English    :  Badajoz is a city in Spain.
# Predicted English :  Badajoz is a city in Spain.
# GLEU Score        :  1.0
# 74
# Spanish           :  Sin la mutación aleatoria de genes no habría evolución.
# Actual English    :  Without the random mutation of genes there would be no evolution.
# Predicted English :  Without the random mutation of genes, there would be no evolution.
# GLEU Score        :  0.46153846153846156
# 75
# Spanish           :  Está un poco más lejos.
# Actual English    :  It's a bit further way.
# Predicted English :  It's a little further.
# GLEU Score        :  0.2857142857142857
# 76
# Spanish           :  De algún modo conseguimos volver a casa, aunque estábamos muy borrachos.
# Actual English    :  We somehow managed to get home, even though we were very drunk.
# Predicted English :  We managed to get home somehow, even though we were very drunk.
# GLEU Score        :  0.45714285714285713
# 77
# Spanish           :  Finalmente entiendo.
# Actual English    :  I finally understand.
# Predicted English :  I finally get it.
# GLEU Score        :  0.26666666666666666
# 78
# Spanish           :  No sé quién está al frente del negocio.
# Actual English    :  I don't know who's in charge of the business.
# Predicted English :  I don't know who's in charge of the business.
# GLEU Score        :  1.0
# 79
# Spanish           :  Este es un callejón sin salida.
# Actual English    :  This is a dead end alley.
# Predicted English :  This is a cul de sac.
# GLEU Score        :  0.25
# 80
# Spanish           :  ¿Por qué no hay ositos de gominola azules?
# Actual English    :  Why aren't there any blue gummy bears?
# Predicted English :  Why are there no blue gummy bears?
# GLEU Score        :  0.3111111111111111
# 81
# Spanish           :  Debe de estar en la cama enfermo.
# Actual English    :  She must be ill in bed.
# Predicted English :  He must be sick in bed.
# GLEU Score        :  0.32142857142857145
# 82
# Spanish           :  Es mi amigo.
# Actual English    :  This is my friend.
# Predicted English :  He's my friend.
# GLEU Score        :  0.4
# 83
# Spanish           :  Anne estaba a punto de salir de casa cuando el teléfono empezó a sonar.
# Actual English    :  Anne was just about to leave the house when the phone began ringing.
# Predicted English :  Anne was about to leave home when the phone started ringing.
# GLEU Score        :  0.17142857142857143
# 84
# Spanish           :  No exponga la consola o los accesorios a altas temperaturas, alta humedad o directamente a la luz del sol use en un entorno donde las temperaturas varíen desde 5 ºC a 35 ºC, o 41 ºF a 95 ºF.
# Actual English    :  Do not expose the console or accessories to high temperatures, high humidity or direct sunlight use in an environment where temperatures range from 5 °C to 35 °C or 41 °F to 95 °F.
# Predicted English :  Do not expose the console or accessories to high temperatures, high humidity or directly in sunlight use in an environment where temperatures vary from 5 °C to 35 °C, or 41 °F to 95 °F.
# GLEU Score        :  0.24561403508771928
# 85
# Spanish           :  Eres un perro.
# Actual English    :  You're a dog.
# Predicted English :  You're a dog.
# GLEU Score        :  1.0
# 86
# Spanish           :  Tenés que saber todo si querés pasar esa prueba.
# Actual English    :  You need to know everything if you want to pass this test.
# Predicted English :  You need to know everything if you want to pass that test.
# GLEU Score        :  0.6373626373626373
# 87
# Spanish           :  ?Eso no es una frase.
# Actual English    :  That's not a sentence.
# Predicted English :  That's not a sentence.
# GLEU Score        :  1.0
# 88
# Spanish           :  El sábado no necesita ir al trabajo.
# Actual English    :  He doesn't have to go to work on Saturday.
# Predicted English :  You don't have to go to work on Saturday.
# GLEU Score        :  0.6818181818181818
# 89
# Spanish           :  Tom está en el jardín.
# Actual English    :  Tom is in the garden.
# Predicted English :  Tom is in the garden.
# GLEU Score        :  1.0
# 90
# Spanish           :  Tenemos que avisarles.
# Actual English    :  We must warn them.
# Predicted English :  We must warn them.
# GLEU Score        :  1.0
# 91
# Spanish           :  Yo no te di un regalo.
# Actual English    :  I didn't get you a present.
# Predicted English :  I didn't give you a present.
# GLEU Score        :  0.4444444444444444
# 92
# Spanish           :  El primer paso siempre es el más difícil.
# Actual English    :  The first step is always the hardest.
# Predicted English :  The first step is always the hardest.
# GLEU Score        :  1.0
# 93
# Spanish           :  Solo dormí dos horas.
# Actual English    :  I only slept two hours.
# Predicted English :  I only slept for two hours.
# GLEU Score        :  0.42857142857142855
# 94
# Spanish           :  Mary toca el piano.
# Actual English    :  Mary plays the piano.
# Predicted English :  Mary plays the piano.
# GLEU Score        :  1.0
# 95
# Spanish           :  ¿Encontraron algo interesante?
# Actual English    :  Found anything interesting?
# Predicted English :  Did you find anything interesting?
# GLEU Score        :  0.2857142857142857
# 96
# Spanish           :  Ella lo dice en serio.
# Actual English    :  She means it.
# Predicted English :  She is serious.
# GLEU Score        :  0.2
# 97
# Spanish           :  No podía ir.
# Actual English    :  I couldn't go.
# Predicted English :  I couldn't go.
# GLEU Score        :  1.0
# 98
# Spanish           :  Allá harás amigos.
# Actual English    :  You will get friends there.
# Predicted English :  You'll make friends there.
# GLEU Score        :  0.3333333333333333
# 99
# Spanish           :  Quizá vuelva.
# Actual English    :  She might come back.
# Predicted English :  He might return.
# GLEU Score        :  0.13333333333333333
# 100
# Spanish           :  Tengo que admitir que estoy un poco ansioso.
# Actual English    :  I have to admit that I'm a little anxious.
# Predicted English :  I have to admit I'm a little anxious.
# GLEU Score        :  0.4696969696969697
# 101
# Spanish           :  Yo sólo trato de protegerte.
# Actual English    :  I'm only trying to protect you.
# Predicted English :  I'm only trying to protect you.
# GLEU Score        :  1.0
# 102
# Spanish           :  Lo que el profesor dijo hizo que Mary empezara a tener sudores fríos.
# Actual English    :  What the teacher said made Mary break out into a cold sweat.
# Predicted English :  What the teacher said made Mary start to get cold sweaty.
# GLEU Score        :  0.25274725274725274
# 103
# Spanish           :  Puede que haya perdido el tren.
# Actual English    :  She might have missed the train.
# Predicted English :  He may have missed the train.
# GLEU Score        :  0.5357142857142857
# 104
# Spanish           :  Conduciendo con precaución, puedes evitar accidentes.
# Actual English    :  Driving carefully, you'll be able to avoid accidents.
# Predicted English :  By driving carefully, you can avoid accidents.
# GLEU Score        :  0.18181818181818182
# 105
# Spanish           :  Se prohibió la exportación de armas.
# Actual English    :  The export of weapons was prohibited.
# Predicted English :  The export of arms was prohibited.??????????????????????????????????????????????????????????????????????????????????????????????????????????????????????
# GLEU Score        :  0.0009032258064516129
# 106
# Spanish           :  Tom rompió las reglas.
# Actual English    :  Tom broke the rules.
# Predicted English :  Tom broke the rules.
# GLEU Score        :  1.0
# 107
# Spanish           :  Ponte hielo en el tobillo para contener la inflamación.
# Actual English    :  Put some ice on your ankle to keep the swelling down.
# Predicted English :  Put some ice on your ankle to hold back the inflammation.
# GLEU Score        :  0.38461538461538464
# 108
# Spanish           :  La violencia estalló por toda la ciudad a causa de la escasez de comida.
# Actual English    :  Violence erupted all over the city because of the food shortages.
# Predicted English :  The violence broke out all over the city because of the food shortage.
# GLEU Score        :  0.3523809523809524
# 109
# Spanish           :  Soy aficionada al fútbol.
# Actual English    :  I am fan of football.
# Predicted English :  I'm fond of soccer.
# GLEU Score        :  0.14285714285714285
# 110
# Spanish           :  No estamos aquí para deteneros.
# Actual English    :  We're not here to arrest you.
# Predicted English :  We're not here to arrest you.
# GLEU Score        :  1.0
# 111
# Spanish           :  Llevasteis las ovejas al mercado.
# Actual English    :  You took the sheep to the market.
# Predicted English :  You took the sheep to the market.
# GLEU Score        :  1.0
# 112
# Spanish           :  Quiero que vengas aquí.
# Actual English    :  I want you to come here.
# Predicted English :  I want you to come here.
# GLEU Score        :  1.0
# 113
# Spanish           :  No me deja pedirte.
# Actual English    :  He won't let me ask you.
# Predicted English :  He won't let me ask you.
# GLEU Score        :  1.0
# 114
# Spanish           :  La salud es lo más importante.
# Actual English    :  Health is the most important thing.
# Predicted English :  Health is the most important thing.
# GLEU Score        :  1.0
# 115
# Spanish           :  Haz tu trabajo rápidamente.
# Actual English    :  Do your work quickly.
# Predicted English :  Do your work quickly.
# GLEU Score        :  1.0
# 116
# Spanish           :  El silencio a menudo implica el consentimiento.
# Actual English    :  Silence often implies consent.
# Predicted English :  Silence often involves consent.
# GLEU Score        :  0.4
# 117
# Spanish           :  Creo que Tom y Mary son unos inmaduros.
# Actual English    :  I think Tom and Mary are immature.
# Predicted English :  I think Tom and Mary are immature.
# GLEU Score        :  1.0
# 118
# Spanish           :  No hice nada para comer.
# Actual English    :  I didn't make anything to eat.
# Predicted English :  I didn't make anything to eat.
# GLEU Score        :  1.0
# 119
# Spanish           :  Pronto serás capaz de esquiar bien.
# Actual English    :  You'll soon be able to ski well.
# Predicted English :  You'll soon be able to ski well.
# GLEU Score        :  1.0
# 120
# Spanish           :  Por lo que sé, eso no es verdad.
# Actual English    :  As far as I know, that isn't true.
# Predicted English :  As far as I know, that is not true.
# GLEU Score        :  0.5909090909090909
# 121
# Spanish           :  Voy a verle cada dos días.
# Actual English    :  I visit him every other day.
# Predicted English :  I go to see him every other day.
# GLEU Score        :  0.35555555555555557
# 122
# Spanish           :  Negro o blanco, un gato que atrape ratones es un gran gato.
# Actual English    :  Black or white, a cat that catches mice is a great cat.
# Predicted English :  Black or white, a cat that catches mice is a big cat.
# GLEU Score        :  0.6571428571428571
# 123
# Spanish           :  Desde luego que me gustaría ir y ver una película, pero no estoy seguro de que tenga tiempo.
# Actual English    :  Id certainly like to go and watch a film, but Im not sure if I have time.
# Predicted English :  Of course I'd like to go and watch a movie, but I'm not sure I have time.
# GLEU Score        :  0.16017316017316016
# 124
# Spanish           :  No cedió en su empeño.
# Actual English    :  He wouldn't give in.
# Predicted English :  He didn't give up.
# GLEU Score        :  0.23809523809523808
# 125
# Spanish           :  Hoy no tienes que trabajar.
# Actual English    :  You don't have to work today.
# Predicted English :  You don't have to work today.
# GLEU Score        :  1.0
# 126
# Spanish           :  Se ven felices.
# Actual English    :  They look happy.
# Predicted English :  They seem happy.
# GLEU Score        :  0.4
# 127
# Spanish           :  Él es el chico del que te hablé el otro día.
# Actual English    :  He is the boy of whom I spoke the other day.
# Predicted English :  He's the boy I told you about the other day.
# GLEU Score        :  0.19230769230769232
# 128
# Spanish           :  Nací en mil novecientos ochenta y ocho en York.
# Actual English    :  I was born in 1988 in York.
# Predicted English :  I was born in nineteen eighty eight in York.
# GLEU Score        :  0.2909090909090909
# 129
# Spanish           :  Déjame probarlo.
# Actual English    :  Let me try it.
# Predicted English :  Let me have a try.
# GLEU Score        :  0.23809523809523808
# 130
# Spanish           :  Él visitó Londres.
# Actual English    :  He visited London.
# Predicted English :  He visited London.
# GLEU Score        :  1.0
# 131
# Spanish           :  Se separaron tras 7 años de matrimonio.
# Actual English    :  They broke up after 7 years of marriage.
# Predicted English :  They split up after 7 years of marriage.
# GLEU Score        :  0.6444444444444445
# 132
# Spanish           :  Por favor, no camines tan rápido.
# Actual English    :  Please don't walk so fast.
# Predicted English :  Please don't walk so fast.
# GLEU Score        :  1.0
# 133
# Spanish           :  Muéstrame lo que tienes en el bolsillo.
# Actual English    :  Show me what's in your pocket.
# Predicted English :  Show me what you have in your pocket.
# GLEU Score        :  0.35555555555555557
# 134
# Spanish           :  Tom dedicó su vida a ayudar a los pobres.
# Actual English    :  Tom devoted his life to helping the poor.
# Predicted English :  Tom dedicated his life to helping the poor.
# GLEU Score        :  0.6444444444444445
# 135
# Spanish           :  Tom ama leer.
# Actual English    :  Tom loves reading.
# Predicted English :  Tom loves to read.
# GLEU Score        :  0.26666666666666666
# 136
# Spanish           :  ¡Así que es ahí a donde va a parar todo mi chocolate!
# Actual English    :  So that's where all my chocolate goes!
# Predicted English :  So that's where all my chocolate goes!
# GLEU Score        :  1.0
# 137
# Spanish           :  Pat voló su servilleta de la mesa estornudando.
# Actual English    :  Pat sneezed the napkin off the table.
# Predicted English :  Pat blew his table towel sneezing.
# GLEU Score        :  0.08333333333333333
# 138
# Spanish           :  Juan se formó en sistemas de información, pero no trabaja con computadoras.
# Actual English    :  John was trained in information systems, but he doesn't work with computers.
# Predicted English :  John was educated in information systems, but doesn't work with computers.
# GLEU Score        :  0.325
# 139
# Spanish           :  Ya sé lo que pasó.
# Actual English    :  I already know what happened.
# Predicted English :  I already know what happened.
# GLEU Score        :  1.0
# 140
# Spanish           :  Las siguientes cuatro a seis semanas son cruciales para controlar el masivo estallido del Ébola.
# Actual English    :  The next four to six weeks are crucial in controlling the massive Ebola outbreak.
# Predicted English :  The next four to six weeks are crucial to controlling the massive outbreak of Ebola.
# GLEU Score        :  0.33088235294117646
# 141
# Spanish           :  Dale la mano.
# Actual English    :  Shake hands with him.
# Predicted English :  Shake his hand.
# GLEU Score        :  0.13333333333333333
# 142
# Spanish           :  Habrá una crisis económica a finales de este año.
# Actual English    :  There will be an economic crisis at the end of this year.
# Predicted English :  There will be an economic crisis at the end of this year.
# GLEU Score        :  1.0
# 143
# Spanish           :  Mi médico me ha aconsejado dejar de tomar este medicamento.
# Actual English    :  My doctor has advised me to stop taking this medicine.
# Predicted English :  My doctor has advised me to stop taking this medicine.
# GLEU Score        :  1.0
# 144
# Spanish           :  Tom durmió casi todo el camino.
# Actual English    :  Tom slept nearly the whole way.
# Predicted English :  Tom slept almost all the way.
# GLEU Score        :  0.25
# 145
# Spanish           :  Si no tenés plata, yo te banco.
# Actual English    :  If you don't have money, I will lend some to you.
# Predicted English :  If you have no money, I'll bank you.
# GLEU Score        :  0.12380952380952381
# 146
# Spanish           :  A Tom le gustó su coche.
# Actual English    :  Tom liked his car.
# Predicted English :  Tom liked his car.
# GLEU Score        :  1.0
# 147
# Spanish           :  Esta es la iglesia en la que nos casamos.
# Actual English    :  This is the church where we got married.
# Predicted English :  This is the church where we got married.
# GLEU Score        :  1.0
# 148
# Spanish           :  Tom la pasó realmente bien.
# Actual English    :  Tom had a really great time.
# Predicted English :  Tom had a really good time.
# GLEU Score        :  0.4642857142857143
# 149
# Spanish           :  También compré una.
# Actual English    :  I bought one, too.
# Predicted English :  I bought one, too.
# GLEU Score        :  1.0
# 150
# Spanish           :  Mucha gente se siente igual que Tom.
# Actual English    :  A lot of people feel the same way Tom does.
# Predicted English :  A lot of people feel the same way Tom does.
# GLEU Score        :  1.0
# 151
# Spanish           :  En la clase de gimnasia, Tom tenía miedo de exponerse como gay por estar mirando demasiado a sus compañeros sin camiseta.
# Actual English    :  In gym class, Tom was afraid to out himself by staring too much at shirtless classmates.
# Predicted English :  In P.E. class, Tom was afraid of showing up like gay because he was looking too much at his students without a T shirt.
# GLEU Score        :  0.06084656084656084
# 152
# Spanish           :  Alquilé una casa con garaje.
# Actual English    :  I rented a house with a garage.
# Predicted English :  I rented a house with a garage.
# GLEU Score        :  1.0
# 153
# Spanish           :  Ella tiene algunos libros.
# Actual English    :  She has a few books.
# Predicted English :  She has some books.
# GLEU Score        :  0.2857142857142857
# 154
# Spanish           :  No tengo enemigos.
# Actual English    :  I don't have any enemies.
# Predicted English :  I have no enemies.
# GLEU Score        :  0.17857142857142858
# 155
# Spanish           :  ¿Por qué hiciste eso?
# Actual English    :  Why did you do it?
# Predicted English :  Why did you do that?
# GLEU Score        :  0.5238095238095238
# 156
# Spanish           :  Él está rizando el rizo.
# Actual English    :  He is making things more difficult for no reason.
# Predicted English :  He is curling the curler.
# GLEU Score        :  0.07272727272727272
# 157
# Spanish           :  Solías admirar a tu padre.
# Actual English    :  You used to look up to your father.
# Predicted English :  You used to look up to your father.
# GLEU Score        :  1.0
# 158
# Spanish           :  ¿Es así?
# Actual English    :  Is that so?
# Predicted English :  Is that so?
# GLEU Score        :  1.0
# 159
# Spanish           :  Linda fue al parque para escuchar la música.
# Actual English    :  Linda went to the park to listen to the music.
# Predicted English :  Linda went to the park to listen to the music.
# GLEU Score        :  1.0
# 160
# Spanish           :  Ella hace como si estuviera enferma.
# Actual English    :  She's acting like she's sick.
# Predicted English :  She pretends to be sick.
# GLEU Score        :  0.1111111111111111
# 161
# Spanish           :  Bueno, han pasado cosas aún más extrañas.
# Actual English    :  Well, stranger things have happened.
# Predicted English :  Well, even stranger things have happened.
# GLEU Score        :  0.5
# 162
# Spanish           :  ¿Cómo abro un archivo?
# Actual English    :  How do I open a file?
# Predicted English :  How do I open a file?
# GLEU Score        :  1.0
# 163
# Spanish           :  Quiero hacer todo lo que Tom hizo.
# Actual English    :  I want to do everything Tom did.
# Predicted English :  I want to do everything Tom did.
# GLEU Score        :  1.0
# 164
# Spanish           :  ¡El latín es la lengua del futuro!
# Actual English    :  Latin is the language of the future!
# Predicted English :  Latin is the language of the future!
# GLEU Score        :  1.0
# 165
# Spanish           :  No puedo creer que estuviese ahí.
# Actual English    :  I can't believe I'm really here.
# Predicted English :  I can't believe I was there.
# GLEU Score        :  0.35555555555555557
# 166
# Spanish           :  Todo el material debe producirse de manera trilingüe para satisfacer las necesidades de nuestros clientes.
# Actual English    :  All materials must be produced trilingually to meet the needs of our customers.
# Predicted English :  All materials must be trilingual in order to meet the needs of our customers.
# GLEU Score        :  0.38333333333333336
# 167
# Spanish           :  La última vez que lo vi, estaba muy bien.
# Actual English    :  The last time when I saw him, he was quite well.
# Predicted English :  When I saw him last, he was doing very well.
# GLEU Score        :  0.17582417582417584
# 168
# Spanish           :  No quiero cometer el mismo error que Tom.
# Actual English    :  I don't want to make the same mistake Tom made.
# Predicted English :  I don't want to make the same mistake Tom made.
# GLEU Score        :  1.0
# 169
# Spanish           :  ¿Entendieron?
# Actual English    :  Did they understand?
# Predicted English :  Did you understand?
# GLEU Score        :  0.4
# 170
# Spanish           :  ¿De verdad quieres hacerlo?
# Actual English    :  Do you really want to do that?
# Predicted English :  Do you really want to do that?
# GLEU Score        :  1.0
# 171
# Spanish           :  Taro, ve a lavarte los dientes.
# Actual English    :  Taro, go brush your teeth.
# Predicted English :  Taro, go brush your teeth.
# GLEU Score        :  1.0
# 172
# Spanish           :  ¿Estás listo para hacer esto?
# Actual English    :  Are you ready to do this?
# Predicted English :  Are you ready to do this?
# GLEU Score        :  1.0
# 173
# Spanish           :  ¡Qué estrechas son estas escaleras!
# Actual English    :  What narrow stairs!
# Predicted English :  How narrow these stairs are!
# GLEU Score        :  0.14285714285714285
# 174
# Spanish           :  Te veré ahí dentro.
# Actual English    :  I'll see you in there.
# Predicted English :  I'll meet you in there.
# GLEU Score        :  0.4642857142857143
# 175
# Spanish           :  El bebé está despierto.
# Actual English    :  The baby's awake.
# Predicted English :  The baby is awake.
# GLEU Score        :  0.4
# 176
# Spanish           :  ¿Les gusta oír música o cantar canciones?
# Actual English    :  Do you like listening to music or singing songs?
# Predicted English :  Do you like listening to music or singing songs?
# GLEU Score        :  1.0
# 177
# Spanish           :  ¿Estás poniendo atención?
# Actual English    :  Have you been paying attention?
# Predicted English :  Are you paying attention?
# GLEU Score        :  0.3333333333333333
# 178
# Spanish           :  ¿Qué están haciendo ellos allá arriba?
# Actual English    :  What are they doing up there?
# Predicted English :  What are they doing up there?
# GLEU Score        :  1.0
# 179
# Spanish           :  Ella es amable.
# Actual English    :  She is gentle.
# Predicted English :  She is kind.
# GLEU Score        :  0.4
# 180
# Spanish           :  Tom le debía dinero a Mary.
# Actual English    :  Tom owed Mary money.
# Predicted English :  Tom owed Mary money.
# GLEU Score        :  1.0
# 181
# Spanish           :  ¿Esa es tu respuesta?
# Actual English    :  Is that your answer?
# Predicted English :  Is that your answer?
# GLEU Score        :  1.0
# 182
# Spanish           :  Si yo fuera un chico, podría apuntarme al equipo de béisbol.
# Actual English    :  If I were a boy, I could join a baseball team.
# Predicted English :  If I were a boy, I could join the baseball team.
# GLEU Score        :  0.5604395604395604
# 183
# Spanish           :  El Viejo Testamento es la primera parte de la Biblia.
# Actual English    :  The Old Testament is the first part of the Bible.
# Predicted English :  The Old Testament is the first part of the Bible.
# GLEU Score        :  1.0
# 184
# Spanish           :  Nos conoce muy bien.
# Actual English    :  He knows us very well.
# Predicted English :  He knows us very well.
# GLEU Score        :  1.0
# 185
# Spanish           :  Compré una revista en la tienda junto a la salida de la estación.
# Actual English    :  I bought a magazine at a store just outside the station.
# Predicted English :  I bought a magazine at the store just outside the station.
# GLEU Score        :  0.46153846153846156
# 186
# Spanish           :  El prófugo se dio a la fuga hacia la frontera.
# Actual English    :  The fugitive made a run for the border.
# Predicted English :  The fugitive took flight to the border.
# GLEU Score        :  0.2
# 187
# Spanish           :  ¿Has oído hablar del accidente?
# Actual English    :  Have you heard about the accident?
# Predicted English :  Have you heard about the accident?
# GLEU Score        :  1.0
# 188
# Spanish           :  Trace usted una línea aquí.
# Actual English    :  Draw a line here.
# Predicted English :  Draw a line here.
# GLEU Score        :  1.0
# 189
# Spanish           :  Pienso que vendrá.
# Actual English    :  I think he'll come.
# Predicted English :  I think he will come.
# GLEU Score        :  0.42857142857142855
# 190
# Spanish           :  Tengo que entregar este reporte antes de las 230.
# Actual English    :  I have to turn in this report by 230.
# Predicted English :  I have to turn in this report by 230.
# GLEU Score        :  1.0
# 191
# Spanish           :  ¿Me extrañaste?
# Actual English    :  Have you missed me?
# Predicted English :  Did you miss me?
# GLEU Score        :  0.26666666666666666
# 192
# Spanish           :  ¿Qué hay de malo en cómo lo hicimos?
# Actual English    :  What's wrong with the way we did it?
# Predicted English :  What was so wrong with how we did it?
# GLEU Score        :  0.2545454545454545
# 193
# Spanish           :  Dígame en dónde vive.
# Actual English    :  Tell me where you live.
# Predicted English :  Tell me where you live.
# GLEU Score        :  1.0
# 194
# Spanish           :  Se ve como algo del futuro.
# Actual English    :  It looks like something out of the future.
# Predicted English :  It looks like something about the future.
# GLEU Score        :  0.35555555555555557
# 195
# Spanish           :  ¿Creés que es estúpido?
# Actual English    :  Do you think this is stupid?
# Predicted English :  Do you think it's stupid?
# GLEU Score        :  0.32142857142857145
# 196
# Spanish           :  Las pinturas de Picasso me parecen extrañas.
# Actual English    :  Picasso's paintings seem strange to me.
# Predicted English :  Picasso's paintings seem strange to me.
# GLEU Score        :  1.0
# 197
# Spanish           :  Mi cepillo de pelo está hecho de madera.
# Actual English    :  My hairbrush is made of wood.
# Predicted English :  My hairbrush is made of wood.
# GLEU Score        :  1.0
# 198
# Spanish           :  ¿Por qué no llamaste por teléfono?
# Actual English    :  Why didn't you call?
# Predicted English :  Why didn't you phone?
# GLEU Score        :  0.5238095238095238
# 199
# Spanish           :  Me bajaré en la última estación.
# Actual English    :  I'll get off at the last station.
# Predicted English :  I'm getting off at the last station.
# GLEU Score        :  0.4888888888888889
# 200
# Spanish           :  Ella se fue deteriorando con la edad.
# Actual English    :  She was weary with age.
# Predicted English :  She was deteriorating with age.
# GLEU Score        :  0.42857142857142855
# 201
# Spanish           :  Un niño de cinco años puede hablar.
# Actual English    :  A five year old boy can talk.
# Predicted English :  A five year old can speak.
# GLEU Score        :  0.3333333333333333
# 202
# Spanish           :  Nadie me consoló cuando yo estaba triste.
# Actual English    :  No one consoled me when I was sad.
# Predicted English :  No one comforted me when I was sad.
# GLEU Score        :  0.5333333333333333
# 203
# Spanish           :  Esta camisa necesita ser planchada.
# Actual English    :  This shirt needs ironing.
# Predicted English :  This shirt needs to be ironed.
# GLEU Score        :  0.25
# 204
# Spanish           :  Me gusta ir a caminar al parque.
# Actual English    :  I like going for a walk in the park.
# Predicted English :  I like to go for a walk in the park.
# GLEU Score        :  0.4696969696969697
# 205
# Spanish           :  Con que esté un poquito amarguito, no me molesta.
# Actual English    :  I don't mind if it's a little bit bitter.
# Predicted English :  Since I'm a little bit woozy, it doesn't bother me.
# GLEU Score        :  0.09523809523809523
# 206
# Spanish           :  El auto enfrente mío es de Karam.
# Actual English    :  The car that's in front of me is Karam's.
# Predicted English :  The car in front of me is Karam's.
# GLEU Score        :  0.5
# 207
# Spanish           :  Noruega es el país más rico en el mundo.
# Actual English    :  Norway is the richest country in the world.
# Predicted English :  Norway is the richest country in the world.
# GLEU Score        :  1.0
# 208
# Spanish           :  Creo que ella está fingiendo.
# Actual English    :  I think she's faking.
# Predicted English :  I think she's faking.
# GLEU Score        :  1.0
# 209
# Spanish           :  ¡Si ella lo descubre, estoy arruinado!.
# Actual English    :  If she finds out, I'm screwed!.
# Predicted English :  If she finds out, I'm ruined!.
# GLEU Score        :  0.5636363636363636
# 210
# Spanish           :  Ese equipo siempre va en último lugar.
# Actual English    :  That team is always in the cellar.
# Predicted English :  That team is always in the last place.
# GLEU Score        :  0.4888888888888889
# 211
# Spanish           :  Siempre comete el mismo error.
# Actual English    :  He always makes the same mistake.
# Predicted English :  He always makes the same mistake.
# GLEU Score        :  1.0
# 212
# Spanish           :  El corredor apretó en la última vuelta.
# Actual English    :  The runner sprinted on the last lap.
# Predicted English :  The runner caught the last round.
# GLEU Score        :  0.19444444444444445
# 213
# Spanish           :  Fracasarás.
# Actual English    :  You will fail.
# Predicted English :  You'll fail.
# GLEU Score        :  0.4
# 214
# Spanish           :  ¿Cuál es tu película romántica preferida?
# Actual English    :  What's your favorite romantic movie?
# Predicted English :  What's your favorite romantic movie?
# GLEU Score        :  1.0
# 215
# Spanish           :  Ellos odian las normas.
# Actual English    :  They hate the rules.
# Predicted English :  They hate the rules.
# GLEU Score        :  1.0
# 216
# Spanish           :  ¿Cuál es tu guitarra?
# Actual English    :  Which is your guitar?
# Predicted English :  Which guitar is yours?
# GLEU Score        :  0.26666666666666666
# 217
# Spanish           :  Él hace buen uso de sus talentos.
# Actual English    :  He makes good use of his talents.
# Predicted English :  He makes good use of his talents.
# GLEU Score        :  1.0
# 218
# Spanish           :  No tengo dónde dormir hoy.
# Actual English    :  I don't have a place to sleep today.
# Predicted English :  I have nowhere to sleep today.
# GLEU Score        :  0.21818181818181817
# 219
# Spanish           :  ¿Qué hay debajo de tu cama?
# Actual English    :  What's that under your bed?
# Predicted English :  What is under your bed?
# GLEU Score        :  0.39285714285714285
# 220
# Spanish           :  Ya me iba.
# Actual English    :  I was just leaving.
# Predicted English :  I was leaving.
# GLEU Score        :  0.4
# 221
# ...
# Actual English    :  We're going to the cinema. Come with us.
# Predicted English :  We are going to the movies. Come with us.
# GLEU Score        :  0.3333333333333333
# 422
# Spanish           :  Tendrán miedo.
# Actual English    :  They'll be afraid.
# Predicted English :  They'll be afraid.
# GLEU Score        :  1.0
# 423
# Spanish           :  Quiero saber más sobre los padres biológicos de Tom.
# Actual English    :  I want to know more about Tom's biological parents.
# Predicted English :  I want to know more about Tom's biological parents.
# GLEU Score        :  1.0
# 424
# Spanish           :  Luego vuelvo.
# Actual English    :  I'll come back later.
# Predicted English :  I'll be back later.
# GLEU Score        :  0.42857142857142855
# 425
# Spanish           :  Karis es austríaca.
# Actual English    :  Karis is Austrian.
# Predicted English :  Karis is an Austrian.
# GLEU Score        :  0.4
# 426
# Spanish           :  Tom siempre juega a ganador.
# Actual English    :  Tom always plays to win.
# Predicted English :  Tom always plays the game of a winner.
# GLEU Score        :  0.15555555555555556
# 427
# Spanish           :  El agua está húmeda.
# Actual English    :  Water is wet.
# Predicted English :  The water is wet.
# GLEU Score        :  0.4
# 428
# Spanish           :  Hable más despacio, por favor.
# Actual English    :  Speak slower, please.
# Predicted English :  Speak more slowly, please.
# GLEU Score        :  0.3333333333333333
# 429
# Spanish           :  Tom no pudo descubrirlo.
# Actual English    :  Tom couldn't figure it out.
# Predicted English :  Tom couldn't find out.
# GLEU Score        :  0.32142857142857145
# 430
# Spanish           :  No sé qué más pueda decir.
# Actual English    :  I don't know what more I can say.
# Predicted English :  I don't know what else I can say.
# GLEU Score        :  0.45454545454545453
# 431
# Spanish           :  El cliente habló con su abogado.
# Actual English    :  The client talked with the lawyer.
# Predicted English :  The client talked to his lawyer.
# GLEU Score        :  0.32142857142857145
# 432
# Spanish           :  Esta flor es de color violáceo.
# Actual English    :  This flower is violet in color.
# Predicted English :  This flower is violet in color.
# GLEU Score        :  1.0
# 433
# Spanish           :  ¿Y si se equivocan?
# Actual English    :  What if they're wrong?
# Predicted English :  What if they're wrong?
# GLEU Score        :  1.0
# 434
# Spanish           :  El hombre me acusó de irresponsable.
# Actual English    :  The man charged me with being irresponsible.
# Predicted English :  The man accused me of irresponsible.
# GLEU Score        :  0.19444444444444445
# 435
# Spanish           :  Somos primos.
# Actual English    :  We're cousins.
# Predicted English :  We are cousins.
# GLEU Score        :  0.4
# 436
# Spanish           :  Tom y Mary viven en nuestra manzana.
# Actual English    :  Tom and Mary live on our block.
# Predicted English :  Tom and Mary live in our apple.
# GLEU Score        :  0.3333333333333333
# 437
# Spanish           :  No miré bajo el sofá.
# Actual English    :  I didn't look under the couch.
# Predicted English :  I didn't look under the couch.
# GLEU Score        :  1.0
# 438
# Spanish           :  Ten en cuenta que tú aquí eres un invitado y deberías comportarte como corresponde.
# Actual English    :  Bear in mind that you're a guest here and should behave accordingly.
# Predicted English :  Keep in mind that you are a guest here and you should behave properly.
# GLEU Score        :  0.2
# 439
# Spanish           :  A Tom se le rompió el cuello en un accidente de esquí.
# Actual English    :  Tom got his neck broken in a ski accident.
# Predicted English :  Tom's neck broke in a ski accident.
# GLEU Score        :  0.3090909090909091
# 440
# Spanish           :  No vas a creer lo que encontré.
# Actual English    :  You won't believe what I found.
# Predicted English :  You won't believe what I found.
# GLEU Score        :  1.0
# 441
# Spanish           :  Solo unos pocos estudiantes entendieron el asunto.
# Actual English    :  Only a few students understood the matter.
# Predicted English :  Only a few students understood the matter.
# GLEU Score        :  1.0
# 442
# Spanish           :  He guardado esta botella de vino para una ocasión especial.
# Actual English    :  I've been saving this bottle of wine for a special occasion.
# Predicted English :  I've kept this bottle of wine for a special occasion.
# GLEU Score        :  0.5274725274725275
# 443
# Spanish           :  Servíos vosotros mismos.
# Actual English    :  Help yourself.
# Predicted English :  Help yourself.
# GLEU Score        :  1.0
# 444
# Spanish           :  Me he sorprendido por la noticia.
# Actual English    :  I was surprised at the news.
# Predicted English :  I was surprised at the news.
# GLEU Score        :  1.0
# 445
# Spanish           :  Tom tiene que esperar tres horas más.
# Actual English    :  Tom has to wait another three hours.
# Predicted English :  Tom has to wait three more hours.
# GLEU Score        :  0.3888888888888889
# 446
# Spanish           :  Necesitaré su ayuda.
# Actual English    :  I will need your help.
# Predicted English :  I'll need your help.
# GLEU Score        :  0.5238095238095238
# 447
# Spanish           :  Tom puede hablar un poco de francés, pero no de manera fluida.
# Actual English    :  Tom can speak a little French, but he isn't fluent.
# Predicted English :  Tom can speak a little French, but not fluently.
# GLEU Score        :  0.4065934065934066
# 448
# Spanish           :  He perdido mi llave.
# Actual English    :  I have lost my key.
# Predicted English :  I've lost my key.
# GLEU Score        :  0.5238095238095238
# 449
# Spanish           :  Nosotros estábamos a salvo, pero un precio tenía que ser pagado.
# Actual English    :  We were saved, but a price had to be paid.
# Predicted English :  We were safe, but a price had to be paid.
# GLEU Score        :  0.6153846153846154
# 450
# Spanish           :  Tengo dos hermanos.
# Actual English    :  I've got two brothers.
# Predicted English :  I have two brothers.
# GLEU Score        :  0.3333333333333333
# 451
# Spanish           :  Cuidado con los dedos del bebé.
# Actual English    :  Watch the baby's fingers.
# Predicted English :  Watch your baby's fingers.
# GLEU Score        :  0.5238095238095238
# 452
# Spanish           :  Tom estaba solo.
# Actual English    :  Tom was alone.
# Predicted English :  Tom was alone.
# GLEU Score        :  1.0
# 453
# Spanish           :  Tom cortó la pera por la mitad.
# Actual English    :  Tom cut the pear in half.
# Predicted English :  Tom cut the pear in half.
# GLEU Score        :  1.0
# 454
# Spanish           :  ¿Qué necesitas comprar?
# Actual English    :  What do you need to buy?
# Predicted English :  What do you need to buy?
# GLEU Score        :  1.0
# 455
# Spanish           :  Grecia es fantástica.
# Actual English    :  Greece is fantastic.
# Predicted English :  Greece is fantastic.
# GLEU Score        :  1.0
# 456
# Spanish           :  Me senté al lado de John.
# Actual English    :  I sat next to John.
# Predicted English :  I sat down next to John.
# GLEU Score        :  0.4642857142857143
# 457
# Spanish           :  Y dijo Dios Hágase la luz. Y la luz se hizo.
# Actual English    :  And God said Let there be light. And there was light.
# Predicted English :  And God said, Let there be light, and there was light.
# GLEU Score        :  0.24761904761904763
# 458
# Spanish           :  ¿Cómo se cocina arroz sin almidón?
# Actual English    :  How does one cook rice without starch?
# Predicted English :  How do you cook rice without starch?
# GLEU Score        :  0.4444444444444444
# 459
# Spanish           :  La lengua va donde el diente duele.
# Actual English    :  The tongue ever turns to the aching tooth.
# Predicted English :  The tongue goes where the tooth hurts.
# GLEU Score        :  0.13333333333333333
# 460
# Spanish           :  ¿Dónde está Argelia?
# Actual English    :  Where is Algeria?
# Predicted English :  Where is Algeria?
# GLEU Score        :  1.0
# 461
# Spanish           :  He decidido aprender la taquigrafía.
# Actual English    :  I've decided to learn shorthand.
# Predicted English :  I've decided to learn shorthand.
# GLEU Score        :  1.0
# 462
# Spanish           :  Esta región produce minerales preciosos.
# Actual English    :  This region produces precious minerals.
# Predicted English :  This region produces precious minerals.
# GLEU Score        :  1.0
# 463
# Spanish           :  El supermercado no me acepta la tarjeta.
# Actual English    :  In the supermarket, they wouldn't take my credit card.
# Predicted English :  The supermarket doesn't accept my card.
# GLEU Score        :  0.07692307692307693
# 464
# Spanish           :  He depositado el dinero en el banco.
# Actual English    :  I've deposited the money in the bank.
# Predicted English :  I have deposited the money in the bank.
# GLEU Score        :  0.6444444444444445
# 465
# Spanish           :  Creo que esta noche va a helar.
# Actual English    :  I think it'll freeze tonight.
# Predicted English :  I think it'll freeze tonight.
# GLEU Score        :  1.0
# 466
# Spanish           :  Está claro que te incomodo.
# Actual English    :  Clearly, I make you uncomfortable.
# Predicted English :  Clearly, I make you uncomfortable.
# GLEU Score        :  1.0
# 467
# Spanish           :  ¿Cuántos hermanos tienes?
# Actual English    :  How many brothers do you have?
# Predicted English :  How many brothers do you have?
# GLEU Score        :  1.0
# 468
# Spanish           :  Ella se casó cuando tenía 17.
# Actual English    :  She got married at the age of 17.
# Predicted English :  She got married when she was 17.
# GLEU Score        :  0.2
# 469
# Spanish           :  Sigamos en contacto por e mail.
# Actual English    :  Let's keep in touch by e mail.
# Predicted English :  Let's keep in touch by e mail.
# GLEU Score        :  1.0
# 470
# Spanish           :  La ambición es el germen del que procede todo brote de nobleza.
# Actual English    :  Ambition is the germ from which all growth of nobleness proceeds.
# Predicted English :  Ambition is the germ from which every outbreak of nobleness comes.
# GLEU Score        :  0.32051282051282054
# 471
# Spanish           :  Él sabe cómo cambiar su contraseña.
# Actual English    :  He knows how to change his password.
# Predicted English :  He knows how to change his password.
# GLEU Score        :  1.0
# 472
# Spanish           :  ¿Me dejas el periódico?
# Actual English    :  Can you leave me the newspaper?
# Predicted English :  May I have your paper?
# GLEU Score        :  0.03571428571428571
# 473
# Spanish           :  Sus piernas son largas.
# Actual English    :  Her legs are long.
# Predicted English :  His legs are long.
# GLEU Score        :  0.6666666666666666
# 474
# Spanish           :  Layla debería callarse.
# Actual English    :  Layla should shut her mouth.
# Predicted English :  Layla should shut up.
# GLEU Score        :  0.3333333333333333
# 475
# Spanish           :  Puedo ver a Tom.
# Actual English    :  I can see Tom.
# Predicted English :  I can see Tom.
# GLEU Score        :  1.0
# 476
# Spanish           :  ¿Sigo?
# Actual English    :  Shall I keep going?
# Predicted English :  Shall I continue?
# GLEU Score        :  0.26666666666666666
# 477
# Spanish           :  No soy muy buen actor.
# Actual English    :  I'm not much of an actor.
# Predicted English :  I'm not a very good actor.
# GLEU Score        :  0.25
# 478
# Spanish           :  Sus bigotes postizos empezaron a despegarse de un lado.
# Actual English    :  His fake moustache started to peel off on one side.
# Predicted English :  His false mustaches began to fall apart.
# GLEU Score        :  0.045454545454545456
# 479
# Spanish           :  ¡Mantente hidratado!
# Actual English    :  Stay hydrated!
# Predicted English :  Stay hydrated!
# GLEU Score        :  1.0
# 480
# Spanish           :  Hubo un accidente terrible en la autopista.
# Actual English    :  There was a terrible accident on the freeway.
# Predicted English :  There was a terrible accident on the highway.
# GLEU Score        :  0.6444444444444445
# 481
# Spanish           :  Los americanos rechazaron la oferta.
# Actual English    :  The Americans rejected the offer.
# Predicted English :  Americans refused the offer.
# GLEU Score        :  0.3333333333333333
# 482
# Spanish           :  El sol nos da luz y calor.
# Actual English    :  The sun gives us light and heat.
# Predicted English :  The sun gives us light and heat.
# GLEU Score        :  1.0
# 483
# Spanish           :  Quizá deberíamos preguntarle a Tom.
# Actual English    :  We should probably ask Tom.
# Predicted English :  Maybe we should ask Tom.
# GLEU Score        :  0.3333333333333333
# 484
# Spanish           :  Bienvenida a Tatoeba.
# Actual English    :  Welcome to Tatoeba!
# Predicted English :  Welcome to Tatoeba!
# GLEU Score        :  1.0
# 485
# Spanish           :  Tom está dispuesto a recurrir a la violencia con el fin de conseguir lo que quiere.
# Actual English    :  Tom is ready to resort to violence in order to get what he wants.
# Predicted English :  Tom is willing to resort to violence in order to get what he wants.
# GLEU Score        :  0.675
# 486
# Spanish           :  ¿A qué hora vuelves?
# Actual English    :  What time are you coming back?
# Predicted English :  What time will you be back?
# GLEU Score        :  0.25
# 487
# Spanish           :  En el rincón de la habitación hay una mesa.
# Actual English    :  There is a table in the corner of the room.
# Predicted English :  There's a table in the corner of the room.
# GLEU Score        :  0.696969696969697
# 488
# Spanish           :  Fumar es malo para la salud.
# Actual English    :  Smoking is harmful to your health.
# Predicted English :  Smoking is bad for one's health.
# GLEU Score        :  0.16666666666666666
# 489
# Spanish           :  Todavía no ha ido a Francia pero tiene muchas ganas de ir el año que viene.
# Actual English    :  He still hasn't been to France he really wants to go next year.
# Predicted English :  He hasn't gone to France yet, but he really wants to go next year.
# GLEU Score        :  0.28104575163398693
# 490
# Spanish           :  Usted es muy valiente.
# Actual English    :  You are very brave.
# Predicted English :  You're very brave.
# GLEU Score        :  0.4666666666666667
# 491
# Spanish           :  Te explicaré cómo nadar.
# Actual English    :  I'll tell you how to swim.
# Predicted English :  I'll explain to you how to swim.
# GLEU Score        :  0.4
# 492
# Spanish           :  Tom rara vez mueve un dedo para ayudar a Mary con la casa.
# Actual English    :  Tom hardly ever lifts a finger to help Mary in the house.
# Predicted English :  Tom seldom lifts his finger to help Mary with the house.
# GLEU Score        :  0.1978021978021978
# 493
# Spanish           :  Este día sólo fue una pérdida de tiempo y de dinero.
# Actual English    :  This day was just a waste of time and money.
# Predicted English :  This was just a waste of time and money.
# GLEU Score        :  0.696969696969697
# 494
# Spanish           :  ¿Eres sexualmente activo?
# Actual English    :  Are you sexually active?
# Predicted English :  Are you sexually active?
# GLEU Score        :  1.0
# 495
# Spanish           :  Cuando se casó, sin duda ella pasaba de los 30.
# Actual English    :  She must have been over thirty when she got married.
# Predicted English :  When she got married, she was no doubt over thirty.
# GLEU Score        :  0.1282051282051282
# 496
# Spanish           :  Hice algo malo.
# Actual English    :  I did something wrong.
# Predicted English :  I did something wrong.
# GLEU Score        :  1.0
# 497
# Spanish           :  No comí nada.
# Actual English    :  I didn't eat anything.
# Predicted English :  I ate nothing.
# GLEU Score        :  0.09523809523809523
# 498
# Spanish           :  Las dos ciudades están conectadas por esta autopista.
# Actual English    :  The two cities are connected by this highway.
# Predicted English :  The two cities are connected by this highway.
# GLEU Score        :  1.0
# 499
# Spanish           :  La familia es la familia.
# Actual English    :  Family is family.
# Predicted English :  The family is the family.
# GLEU Score        :  0.19047619047619047
# 500
# Spanish           :  No quería leche.
# Actual English    :  I didn't want milk.
# Predicted English :  I didn't want any milk.
# GLEU Score        :  0.4642857142857143
# 587.3099448680878

# %%
#  to get average of GLEU Score on test dataset
def Average(lst):
    sum_of_list = 0
    for i in range(len(lst)):
        sum_of_list += lst[i]
    average = sum_of_list/len(lst)
    return average

# %%
avg_scores_gleu = Average(sco)

# %%
avg_scores_gleu
# Out:
# 0.6118102138784416

# %% [markdown]
# get individual GBLEU score on train dataset

# %%
train_data = pd.read_csv("/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en-train.csv")

# %%
start_time = time.time()
scos = []
k = 0
for eng, spa in zip(train_data['spanish'], train_data['english']):
  k +=1
  print(k)
  print("Spanish           : ", eng)
  print("Actual English    : ", spa)
  tokenized_data = tokenizer([eng], return_tensors="np", pad_to_multiple_of=128)
  #print(tokenized_data)
  out = generate(tokenized_data)
  with tokenizer.as_target_tokenizer():
    print("Predicted English : ", tokenizer.decode(out[0], skip_special_tokens=True))
    actual_spanish    = nltk.word_tokenize(spa)
    predicted_spanish = nltk.word_tokenize(tokenizer.decode(out[0], skip_special_tokens=True)) 
    scores = corpus_gleu([[actual_spanish]], [predicted_spanish], min_len=1, max_len=128)
    print("GLEU Score        : ", scores)
    scos.append(scores)
    if k ==500:
      now = time.time()
      t_time = now-start_time
      print(t_time)
      break
# Out:
# 1
# Spanish           :  A pesar de sus esfuerzos, no consiguió triunfar.
# Actual English    :  With all his efforts, he couldn't succeed.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3547: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   "`as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your "
# Predicted English :  Despite his efforts, he failed to succeed.
# GLEU Score        :  0.23636363636363636
# 2
# Spanish           :  Nunca se me ocurren ideas brillantes.
# Actual English    :  Bright ideas never occur to me.
# Predicted English :  Bright ideas never occur to me.
# GLEU Score        :  1.0
# 3
# Spanish           :  Tom no tuvo nada que ver con el secuestro.
# Actual English    :  Tom had nothing to do with the kidnapping.
# Predicted English :  Tom had nothing to do with the kidnapping.
# GLEU Score        :  1.0
# 4
# Spanish           :  Nuestras fábricas están funcionando perfectamente.
# Actual English    :  Our factories are working perfectly.
# Predicted English :  Our factories are working perfectly.
# GLEU Score        :  1.0
# 5
# Spanish           :  Le dije que viniese a mi casa.
# Actual English    :  I told him to come to my house.
# Predicted English :  I told him to come to my house.
# GLEU Score        :  1.0
# 6
# Spanish           :  Estoy intentando protegerte.
# Actual English    :  I'm trying to protect you.
# Predicted English :  I'm trying to protect you.
# GLEU Score        :  1.0
# 7
# Spanish           :  ¡Oh, no! ¡Se nos agotó la gasolina!.
# Actual English    :  Oh, no! We're out of gas!.
# Predicted English :  Oh, no! We're out of gas!.
# GLEU Score        :  1.0
# 8
# Spanish           :  Mi padre fuma.
# Actual English    :  My father smokes.
# Predicted English :  My father smokes.
# GLEU Score        :  1.0
# 9
# Spanish           :  No te rindas.
# Actual English    :  Don't give up.
# Predicted English :  Don't give up.
# GLEU Score        :  1.0
# 10
# Spanish           :  Oí un ruiseñor japonés.
# Actual English    :  I heard a Japanese nightingale.
# Predicted English :  I heard a Japanese nightingale.
# GLEU Score        :  1.0
# 11
# Spanish           :  Esto es de plástico.
# Actual English    :  That's plastic.
# Predicted English :  This is plastic.
# GLEU Score        :  0.3
# 12
# Spanish           :  Elvis ha abandonado el edificio.
# Actual English    :  Elvis has left the building.
# Predicted English :  Elvis has left the building.
# GLEU Score        :  1.0
# 13
# Spanish           :  Mi tío conduce un Ford.
# Actual English    :  My uncle drives a Ford.
# Predicted English :  My uncle drives a Ford.
# GLEU Score        :  1.0
# 14
# Spanish           :  Las cuatro hermanas viven en Roma.
# Actual English    :  The four sisters live in Rome.
# Predicted English :  All four sisters live in Rome.
# GLEU Score        :  0.75
# 15
# Spanish           :  Oí que podrías estar en problemas.
# Actual English    :  I heard you might be in trouble.
# Predicted English :  I heard that you might be in trouble.
# GLEU Score        :  0.5333333333333333
# 16
# Spanish           :  ¿Puedo pedir una aclaración?
# Actual English    :  Can I ask for an elucidation?
# Predicted English :  Can I ask for an elucidation?
# GLEU Score        :  1.0
# 17
# Spanish           :  ¡Qué conmovedor!
# Actual English    :  How touching!
# Predicted English :  How touching!
# GLEU Score        :  1.0
# 18
# Spanish           :  La policía piensa que a Tom lo apuñalaron antes de que le cortaran la garganta.
# Actual English    :  The police think that Tom was stabbed before his throat was slit.
# Predicted English :  The police think Tom was stabbed before his throat was slit.
# GLEU Score        :  0.5604395604395604
# 19
# Spanish           :  Ella no hace cosas así.
# Actual English    :  She does not do things like that.
# Predicted English :  She doesn't do things like that.
# GLEU Score        :  0.5
# 20
# Spanish           :  Estoy preocupado por mi futuro.
# Actual English    :  I worry about my future.
# Predicted English :  I'm worried about my future.
# GLEU Score        :  0.39285714285714285
# 21
# Spanish           :  Yo fui al hotel en taxi.
# Actual English    :  I went to the hotel by cab.
# Predicted English :  I went to the hotel by taxi.
# GLEU Score        :  0.6111111111111112
# 22
# Spanish           :  Tom se puso nervioso.
# Actual English    :  Tom became nervous.
# Predicted English :  Tom became nervous.
# GLEU Score        :  1.0
# 23
# Spanish           :  ¡Ten misericordia!
# Actual English    :  Have mercy!
# Predicted English :  Have mercy!
# GLEU Score        :  1.0
# 24
# Spanish           :  Era tan inmaduro que no pudo resistir la tentación.
# Actual English    :  He was so immature, he couldn't resist the temptation.
# Predicted English :  He was so immature that he could not resist the temptation.
# GLEU Score        :  0.2948717948717949
# 25
# Spanish           :  Su voz es realmente profunda.
# Actual English    :  His voice is really deep.
# Predicted English :  His voice is really deep.
# GLEU Score        :  1.0
# 26
# Spanish           :  Tom deseaba poder jugar tenis tan bien como Mary.
# Actual English    :  Tom wished that he could play tennis as well as Mary.
# Predicted English :  Tom wished that he could play tennis as well as Mary.
# GLEU Score        :  1.0
# 27
# Spanish           :  Gracias a Dios por eso.
# Actual English    :  Thank God for that.
# Predicted English :  Thank God for that.
# GLEU Score        :  1.0
# 28
# Spanish           :  ¿Te han diagnosticado de VIH alguna vez?
# Actual English    :  Have you ever been diagnosed with HIV?
# Predicted English :  Have you ever been diagnosed with HIV?
# GLEU Score        :  1.0
# 29
# Spanish           :  Esa idea ni se me pasó por la cabeza.
# Actual English    :  The idea never came into my head.
# Predicted English :  The idea didn't even go through my head.
# GLEU Score        :  0.16363636363636364
# 30
# Spanish           :  No recibí el mensaje a tiempo porque cuando me lo enviaste tenía el móvil sin batería.
# Actual English    :  I did not receive your message on time because when you sent it to me my mobile had no battery.
# Predicted English :  I didn't get the message on time because when you sent it to me my mobile had no battery.
# GLEU Score        :  0.6017316017316018
# 31
# Spanish           :  ¿Puedes cuidar de los niños?
# Actual English    :  Can you watch the kids?
# Predicted English :  Can you take care of the kids?
# GLEU Score        :  0.25
# 32
# Spanish           :  Tom vino a verte.
# Actual English    :  Tom came to see you.
# Predicted English :  Tom came to see you.
# GLEU Score        :  1.0
# 33
# Spanish           :  Disculpa, no conozco tu patronímico.
# Actual English    :  Excuse me, I don't know your patronymic.
# Predicted English :  Excuse me, I don't know your patronymic.
# GLEU Score        :  1.0
# 34
# Spanish           :  Tom se preguntó a quién tendría pensado votar Mary.
# Actual English    :  Tom wondered who Mary was planning to vote for.
# Predicted English :  Tom wondered who Mary was planning to vote for.
# GLEU Score        :  1.0
# 35
# Spanish           :  Por fin he acabado los deberes ahora puedo irme a la cama.
# Actual English    :  I have finally finished my homework now I can go to bed.
# Predicted English :  I'm finally done with my homework now I can go to bed.
# GLEU Score        :  0.44761904761904764
# 36
# Spanish           :  Como se largó repentinamente y solo él tenía las contraseñas, hemos perdido un montón de información valiosa para la compañía.
# Actual English    :  Since he left all of a sudden, and he was the only one with the passwords, we've lost a ton of valuable information for the company.
# Predicted English :  Since he left suddenly and only he had the passwords, we've lost a ton of valuable information for the company.
# GLEU Score        :  0.27741935483870966
# 37
# Spanish           :  No me digas que Tom ya está tomado.
# Actual English    :  Don't tell me that Tom is drunk already.
# Predicted English :  Don't tell me that Tom is drunk already.
# GLEU Score        :  1.0
# 38
# Spanish           :  ¿Eres médico?
# Actual English    :  Are you a doctor?
# Predicted English :  Are you a doctor?
# GLEU Score        :  1.0
# 39
# Spanish           :  Ella decidió no pagar la multa.
# Actual English    :  She resolved not to pay the fine.
# Predicted English :  She decided not to pay the fine.
# GLEU Score        :  0.6111111111111112
# 40
# Spanish           :  Me gustaría conocer a Tom más a fondo.
# Actual English    :  I'd like to get to know Tom.
# Predicted English :  I'd like to get to know Tom.
# GLEU Score        :  1.0
# 41
# Spanish           :  ¿Tu coche es rápido?
# Actual English    :  Is your car fast?
# Predicted English :  Is your car fast?
# GLEU Score        :  1.0
# 42
# Spanish           :  ¿Qué quieres hacer ahora?
# Actual English    :  What do you want to do now?
# Predicted English :  What do you want to do now?
# GLEU Score        :  1.0
# 43
# Spanish           :  ¿Es más divertido ser un niño o un adulto?
# Actual English    :  Is it more fun being a child or an adult?
# Predicted English :  Is it more fun being a child or an adult?
# GLEU Score        :  1.0
# 44
# Spanish           :  No se puede evitar.
# Actual English    :  It cannot be helped.
# Predicted English :  It can't be helped.
# GLEU Score        :  0.3333333333333333
# 45
# Spanish           :  Dan dirigió a los investigadores hasta la escena del crimen.
# Actual English    :  Dan led the investigators to the crime scene.
# Predicted English :  Dan led the investigators to the crime scene.
# GLEU Score        :  1.0
# 46
# Spanish           :  Los demócratas aún no han elegido a sus candidatos, sin embargo, están seguros de todos modos que van a perder.
# Actual English    :  The Democrats haven't decided on their candidates yet, but in any case they're sure to lose.
# Predicted English :  The Democrats haven't chosen their candidates yet, but in any case they're certain to lose.
# GLEU Score        :  0.3380952380952381
# 47
# Spanish           :  ¿Quién aprobó esto?
# Actual English    :  Who approved this?
# Predicted English :  Who approved this?
# GLEU Score        :  1.0
# 48
# Spanish           :  He esperado demasiado tiempo por esto.
# Actual English    :  I've waited for this too long.
# Predicted English :  I've waited for this too long.
# GLEU Score        :  1.0
# 49
# Spanish           :  Los animales corren.
# Actual English    :  The animals run.
# Predicted English :  Animals run.
# GLEU Score        :  0.3
# 50
# Spanish           :  Los palos en una baraja de cartas estándar son tréboles, diamantes, corazones y espadas.
# Actual English    :  The suits in a standard deck of cards are clubs, diamonds, hearts and spades.
# Predicted English :  The suits in a standard deck of cards are clubs, diamonds, hearts and spades.
# GLEU Score        :  1.0
# 51
# Spanish           :  ¿Recuerdas el pueblo en que nació?
# Actual English    :  Do you remember the town in which he was born?
# Predicted English :  Do you remember the town where he was born?
# GLEU Score        :  0.3787878787878788
# 52
# Spanish           :  ¿Cuál fue el sentido de todo esto?
# Actual English    :  What was the point of all of this?
# Predicted English :  What was the point of all of this?
# GLEU Score        :  1.0
# 53
# Spanish           :  Me dan miedo las avispas.
# Actual English    :  I am afraid of wasps.
# Predicted English :  I am afraid of wasps.
# GLEU Score        :  1.0
# 54
# Spanish           :  ¿Qué tan larga es esa historia?
# Actual English    :  How long is that story?
# Predicted English :  How long is that story?
# GLEU Score        :  1.0
# 55
# Spanish           :  Sé cuántos años tiene Tom.
# Actual English    :  I know how old Tom is.
# Predicted English :  I know how old Tom is.
# GLEU Score        :  1.0
# 56
# Spanish           :  Tiene ocho relojes.
# Actual English    :  She has eight watches.
# Predicted English :  He has eight watches.
# GLEU Score        :  0.6666666666666666
# 57
# Spanish           :  Tom y Mary se comportaban como niños.
# Actual English    :  Tom and Mary acted like kids.
# Predicted English :  Tom and Mary acted like children.
# GLEU Score        :  0.5714285714285714
# 58
# Spanish           :  Él vive encima mío.
# Actual English    :  He lives above me.
# Predicted English :  He lives above me.
# GLEU Score        :  1.0
# 59
# Spanish           :  Si hubiera trabajado más duro, podría ser rico ahora.
# Actual English    :  If he had worked harder, he might be a rich man now.
# Predicted English :  If he had worked harder, he could be rich now.
# GLEU Score        :  0.3142857142857143
# 60
# Spanish           :  Eso suena interesante.
# Actual English    :  That sounds really interesting.
# Predicted English :  That sounds interesting.
# GLEU Score        :  0.4
# 61
# Spanish           :  ¿Qué hay frente a ti?
# Actual English    :  What's in front of you?
# Predicted English :  What's in front of you?
# GLEU Score        :  1.0
# 62
# Spanish           :  Siempre fuiste una buena cocinera.
# Actual English    :  You always were a good cook.
# Predicted English :  You always were a good cook.
# GLEU Score        :  1.0
# 63
# Spanish           :  Es una maestra de aquella escuela.
# Actual English    :  She's a teacher at that school.
# Predicted English :  She's a teacher at that school.
# GLEU Score        :  1.0
# 64
# Spanish           :  La falta de alternativas despeja la mente maravillosamente.
# Actual English    :  The absence of alternatives clears the mind marvelously.
# Predicted English :  The absence of alternatives clears the mind marvelously.
# GLEU Score        :  1.0
# 65
# Spanish           :  Tom arrojó el libro de Mary al fuego.
# Actual English    :  Tom threw Mary's book into the fire.
# Predicted English :  Tom threw Mary's book into the fire.
# GLEU Score        :  1.0
# 66
# Spanish           :  También se les preguntó.
# Actual English    :  They were also asked.
# Predicted English :  They were also asked.
# GLEU Score        :  1.0
# 67
# Spanish           :  Tom vandalizó la casa de campo abandonada.
# Actual English    :  Tom vandalized the abandoned farmhouse.
# Predicted English :  Tom vandalized the abandoned cottage.
# GLEU Score        :  0.5238095238095238
# 68
# Spanish           :  ¿Cuántas veces pasó?
# Actual English    :  How many times did it happen?
# Predicted English :  How many times did it happen?
# GLEU Score        :  1.0
# 69
# Spanish           :  Haré lo que pueda para ayudarte.
# Actual English    :  I'll do what I can to help you.
# Predicted English :  I'll do my best to help you.
# GLEU Score        :  0.2909090909090909
# 70
# Spanish           :  Tom dijo buenas noches.
# Actual English    :  Tom said goodnight.
# Predicted English :  Tom said goodnight.
# GLEU Score        :  1.0
# 71
# Spanish           :  Nunca supe su nombre de pila.
# Actual English    :  I never knew his first name.
# Predicted English :  I never knew his first name.
# GLEU Score        :  1.0
# 72
# Spanish           :  Mañana vamos al zoológico, y veremos a todo tipo de animales allí.
# Actual English    :  Tomorrow, we're going to the zoo, and we'll see all kinds of animals there.
# Predicted English :  Tomorrow, we're going to the zoo, and we'll see all kinds of animals there.
# GLEU Score        :  1.0
# 73
# Spanish           :  Es pianista.
# Actual English    :  He is a pianist.
# Predicted English :  He is a pianist.
# GLEU Score        :  1.0
# 74
# Spanish           :  Por más extraño que pueda sonar, lo que Tom dijo es verdad.
# Actual English    :  As strange as it may sound, what Tom said is true.
# Predicted English :  As strange as it may sound, what Tom said is true.
# GLEU Score        :  1.0
# 75
# Spanish           :  ¿Eso es amor?
# Actual English    :  Is that love?
# Predicted English :  Is that love?
# GLEU Score        :  1.0
# 76
# Spanish           :  Soy no binaria.
# Actual English    :  I'm non binary.
# Predicted English :  I'm non binary.
# GLEU Score        :  1.0
# 77
# Spanish           :  Es todo por hoy.
# Actual English    :  Let's call it a day.
# Predicted English :  Let's call it a day today.
# GLEU Score        :  0.6111111111111112
# 78
# Spanish           :  Mi tía viene a Tokio mañana.
# Actual English    :  My aunt is coming to Tokyo tomorrow.
# Predicted English :  My aunt is coming to Tokyo tomorrow.
# GLEU Score        :  1.0
# 79
# Spanish           :  Siempre lo encuentro silbando cuando trabaja en sus pinturas.
# Actual English    :  I always find him whistling while working on his paintings.
# Predicted English :  I always find him whistling while working on his paintings.
# GLEU Score        :  1.0
# 80
# Spanish           :  Tom no creía que Mary fuera capaz de hacer algo semejante.
# Actual English    :  Tom didn't believe that Mary was capable of doing such a thing.
# Predicted English :  Tom didn't believe that Mary was capable of doing such a thing.
# GLEU Score        :  1.0
# 81
# Spanish           :  ¿Sabes cuándo vendrá el músico aquí?
# Actual English    :  Do you know when the musician will come here?
# Predicted English :  Do you know when the musician will come here?
# GLEU Score        :  1.0
# 82
# Spanish           :  Tom cree en los fenómenos paranormales.
# Actual English    :  Tom believes in paranormal phenomena.
# Predicted English :  Tom believes in paranormal phenomena.
# GLEU Score        :  1.0
# 83
# Spanish           :  Él no puede parar de reírse.
# Actual English    :  He can't stop laughing.
# Predicted English :  He can't stop laughing.
# GLEU Score        :  1.0
# 84
# Spanish           :  ¿Tienes cosas que hacer esta noche?
# Actual English    :  Do you have anything to do tonight?
# Predicted English :  Do you have anything to do tonight?
# GLEU Score        :  1.0
# 85
# Spanish           :  Yo intentaba perder tiempo.
# Actual English    :  I was trying to kill time.
# Predicted English :  I was trying to kill time.
# GLEU Score        :  1.0
# 86
# Spanish           :  Tom revendió su casa.
# Actual English    :  Tom resold his home.
# Predicted English :  Tom resold his house.
# GLEU Score        :  0.4666666666666667
# 87
# Spanish           :  El león es león por sus garras.
# Actual English    :  The lion is a lion because of his claws.
# Predicted English :  The lion is a lion because of its claws.
# GLEU Score        :  0.5636363636363636
# 88
# Spanish           :  La página de Tatoeba Wikipedia en español acaba de ser publicada.
# Actual English    :  The Tatoeba Wikipedia page in Spanish has just been published.
# Predicted English :  The Tatoeba Wikipedia page in Spanish has just been published.
# GLEU Score        :  1.0
# 89
# Spanish           :  Es difícil entender por qué quieres irte.
# Actual English    :  It is difficult to understand why you want to go.
# Predicted English :  It's hard to understand why you want to leave.
# GLEU Score        :  0.3484848484848485
# 90
# Spanish           :  Mi hermana tiene un piano.
# Actual English    :  My sister has a piano.
# Predicted English :  My sister has a piano.
# GLEU Score        :  1.0
# 91
# Spanish           :  Te veo este fin de semana.
# Actual English    :  See you on the weekend.
# Predicted English :  See you on the weekend.
# GLEU Score        :  1.0
# 92
# Spanish           :  Es todo lo que puedo hacer por ahora.
# Actual English    :  That's all I can do for now.
# Predicted English :  That's all I can do for now.
# GLEU Score        :  1.0
# 93
# Spanish           :  Cambió radicalmente de postura.
# Actual English    :  He has made an about face.
# Predicted English :  He made an about face.
# GLEU Score        :  0.5714285714285714
# 94
# Spanish           :  Este queso está hecho de leche de oveja.
# Actual English    :  This cheese is made from sheep's milk.
# Predicted English :  This cheese is made from sheep's milk.
# GLEU Score        :  1.0
# 95
# Spanish           :  Meg ni siquiera me miró.
# Actual English    :  Meg didn't even look at me.
# Predicted English :  Meg didn't even look at me.
# GLEU Score        :  1.0
# 96
# Spanish           :  ¡Eso hubiera sido peor!
# Actual English    :  That would have been worse!
# Predicted English :  That would have been worse!
# GLEU Score        :  1.0
# 97
# Spanish           :  No soy tu esposa.
# Actual English    :  I am not your wife.
# Predicted English :  I'm not your wife.
# GLEU Score        :  0.5238095238095238
# 98
# Spanish           :  No hay que exagerar.
# Actual English    :  There's no need to exaggerate.
# Predicted English :  There's no need to exaggerate.
# GLEU Score        :  1.0
# 99
# Spanish           :  Apúrate para que no llegues tarde al almuerzo.
# Actual English    :  Hurry up, otherwise you'll be late for lunch.
# Predicted English :  Hurry up, otherwise you'll be late for lunch.
# GLEU Score        :  1.0
# 100
# Spanish           :  Gracias por tu respuesta.
# Actual English    :  Thanks for your reply.
# Predicted English :  Thanks for your reply.
# GLEU Score        :  1.0
# 101
# Spanish           :  Debemos seguir adelante sacando lo mejor de todos los obstáculos.
# Actual English    :  We must go forward getting the better of all obstacles.
# Predicted English :  We must keep going, getting the better of all obstacles.
# GLEU Score        :  0.3974358974358974
# 102
# Spanish           :  Por favor, márchese.
# Actual English    :  Please leave.
# Predicted English :  Please leave.
# GLEU Score        :  1.0
# 103
# Spanish           :  Tengo un amigo cuya mujer es pianista.
# Actual English    :  I have a friend whose wife is a pianist.
# Predicted English :  I have a friend whose wife is a pianist.
# GLEU Score        :  1.0
# 104
# Spanish           :  No sé qué es lo que sabe.
# Actual English    :  I don't know what he knows.
# Predicted English :  I don't know what he knows.
# GLEU Score        :  1.0
# 105
# Spanish           :  Te recuperarás.
# Actual English    :  You'll get over it.
# Predicted English :  You'll recover.
# GLEU Score        :  0.19047619047619047
# 106
# Spanish           :  Eso es lo que quiero.
# Actual English    :  That's what I want.
# Predicted English :  That's what I want.
# GLEU Score        :  1.0
# 107
# Spanish           :  ¿Qué tipo de cosas almacenas en tu computador?
# Actual English    :  What kinds of things do you have on the computer?
# Predicted English :  What kind of things do you have on your computer?
# GLEU Score        :  0.3787878787878788
# 108
# Spanish           :  ¿Qué inventó Bell?
# Actual English    :  What did Bell invent?
# Predicted English :  What did Bell invent?
# GLEU Score        :  1.0
# 109
# Spanish           :  Ellos pedirían ayuda.
# Actual English    :  They would call for help.
# Predicted English :  They would call for help.
# GLEU Score        :  1.0
# 110
# Spanish           :  Espero que Tom estuviera de broma.
# Actual English    :  I hope Tom was kidding.
# Predicted English :  I hope Tom was kidding.
# GLEU Score        :  1.0
# 111
# Spanish           :  Siéntate aquí, te sentirás mejor.
# Actual English    :  Sit here, you'll feel better.
# Predicted English :  Sit down here, you'll feel better.
# GLEU Score        :  0.6444444444444445
# 112
# Spanish           :  ¿Queréis otro vaso de vino?
# Actual English    :  Would you like another glass of wine?
# Predicted English :  Would you like another glass of wine?
# GLEU Score        :  1.0
# 113
# Spanish           :  Si vas a entrar a la Maligna Liga del Mal, tendrás que tener una risa memorable.
# Actual English    :  If you're gonna get into the Evil League of Evil, you have to have a memorable laugh.
# Predicted English :  If you're going to join the Evil League of Evil, you'll have to have a memorable laugh.
# GLEU Score        :  0.2683982683982684
# 114
# Spanish           :  ¿La conoce?
# Actual English    :  Do you know her?
# Predicted English :  Do you know her?
# GLEU Score        :  1.0
# 115
# Spanish           :  Esta noche llueve a cántaros.
# Actual English    :  It's raining hard tonight.
# Predicted English :  It's raining cats and dogs tonight.
# GLEU Score        :  0.25
# 116
# Spanish           :  ¿Dónde te lavas las manos?
# Actual English    :  Where do you wash your hands?
# Predicted English :  Where do you wash your hands?
# GLEU Score        :  1.0
# 117
# Spanish           :  Sandra gastó el doble de dinero que yo.
# Actual English    :  Sandra spent twice as much as I did.
# Predicted English :  Sandra spent twice as much as I did.
# GLEU Score        :  1.0
# 118
# Spanish           :  Ella salió de la habitación.
# Actual English    :  She came out of the room.
# Predicted English :  She went out of the room.
# GLEU Score        :  0.5714285714285714
# 119
# Spanish           :  El profesor le dijo que reescribiera el ensayo.
# Actual English    :  The teacher told him to rewrite the essay.
# Predicted English :  The teacher told him to rewrite the essay.
# GLEU Score        :  1.0
# 120
# Spanish           :  No le gusta bailar.
# Actual English    :  He doesn't like dancing.
# Predicted English :  He doesn't like to dance.
# GLEU Score        :  0.39285714285714285
# 121
# Spanish           :  Ellos aprenden cómo hacerlo sin ser enseñados.
# Actual English    :  They learn to do without being taught.
# Predicted English :  They learn to do it without being taught.
# GLEU Score        :  0.4444444444444444
# 122
# Spanish           :  Estás tumbado en la cama.
# Actual English    :  You are laying in the bed.
# Predicted English :  You're lying in bed.
# GLEU Score        :  0.17857142857142858
# 123
# Spanish           :  Estamos deseando ayudarle.
# Actual English    :  We're willing to help you.
# Predicted English :  We're willing to help you.
# GLEU Score        :  1.0
# 124
# Spanish           :  El programa no permite cambios a esta altura.
# Actual English    :  The program does not allow for changes at this point in time.
# Predicted English :  The program does not allow for changes at this point in time.
# GLEU Score        :  1.0
# 125
# Spanish           :  Juego al fútbol.
# Actual English    :  I play football.
# Predicted English :  I play soccer.
# GLEU Score        :  0.4
# 126
# Spanish           :  Yo estaba de buen humor.
# Actual English    :  I was in a good mood.
# Predicted English :  I was in a good mood.
# GLEU Score        :  1.0
# 127
# Spanish           :  Él explicó por qué el experimento fracasó.
# Actual English    :  He explained why the experiment failed.
# Predicted English :  He explained why the experiment failed.
# GLEU Score        :  1.0
# 128
# Spanish           :  Salid de la clase.
# Actual English    :  Get out of the classroom.
# Predicted English :  Get out of the classroom.
# GLEU Score        :  1.0
# 129
# Spanish           :  Tom odia la Navidad.
# Actual English    :  Tom hates Christmas.
# Predicted English :  Tom hates Christmas.
# GLEU Score        :  1.0
# 130
# Spanish           :  Vienen.
# Actual English    :  They will come.
# Predicted English :  They're coming.
# GLEU Score        :  0.2
# 131
# Spanish           :  No hace falta sacar conclusiones precipitadas.
# Actual English    :  There is no need to draw a hasty conclusion.
# Predicted English :  There is no need to draw a hasty conclusion.
# GLEU Score        :  1.0
# 132
# Spanish           :  Tiene un lindo culo.
# Actual English    :  He has a nice ass.
# Predicted English :  She has a nice ass.
# GLEU Score        :  0.7142857142857143
# 133
# Spanish           :  Como él estaba cansado, estaba sentado en el sofá con los ojos cerrados.
# Actual English    :  Since he was tired, he was sitting on the sofa with his eyes closed.
# Predicted English :  Since he was tired, he was sitting on the sofa with his eyes closed.
# GLEU Score        :  1.0
# 134
# Spanish           :  Toma algunas galletas para matar el gusanillo hasta la cena.
# Actual English    :  She had some cookies to stay her hunger until dinner.
# Predicted English :  She had some cookies to make a mess of herself until dinner.
# GLEU Score        :  0.23076923076923078
# 135
# Spanish           :  Aquí no hay azúcar.
# Actual English    :  There's no sugar here.
# Predicted English :  There's no sugar here.
# GLEU Score        :  1.0
# 136
# Spanish           :  El pianista está dotado de un talento extraordinario.
# Actual English    :  The pianist is endowed with extraordinary talent.
# Predicted English :  The pianist is endowed with extraordinary talent.
# GLEU Score        :  1.0
# 137
# Spanish           :  Paremos esta locura.
# Actual English    :  Let's stop this madness.
# Predicted English :  Let's stop this madness.
# GLEU Score        :  1.0
# 138
# Spanish           :  Ella exhibió su vestido a propósito.
# Actual English    :  She purposely showed off her dress.
# Predicted English :  She purposely displayed her dress.
# GLEU Score        :  0.32142857142857145
# 139
# Spanish           :  Yo vi a tu hermano el otro día.
# Actual English    :  I saw your brother the other day.
# Predicted English :  I saw your brother the other day.
# GLEU Score        :  1.0
# 140
# Spanish           :  Ustedes son el grupo de apoyo.
# Actual English    :  You are the backing group.
# Predicted English :  You are the backing group.
# GLEU Score        :  1.0
# 141
# Spanish           :  Fue pasada la medianoche cuando llegamos.
# Actual English    :  It was after midnight when we arrived.
# Predicted English :  It was after midnight when we arrived.
# GLEU Score        :  1.0
# 142
# Spanish           :  Bob y Mary tocan la flauta.
# Actual English    :  Bob and Mary play the recorder.
# Predicted English :  Bob and Mary play the flute.
# GLEU Score        :  0.5714285714285714
# 143
# Spanish           :  ¿Realmente podremos aprender una lengua extranjera como un nativo?
# Actual English    :  Can we really learn to speak a foreign language like a native?
# Predicted English :  Can we really learn a foreign language like a native?
# GLEU Score        :  0.4175824175824176
# 144
# Spanish           :  Tom es un empleado.
# Actual English    :  Tom is an employee.
# Predicted English :  Tom is an employee.
# GLEU Score        :  1.0
# 145
# Spanish           :  He visto esta película antes.
# Actual English    :  I have seen the film before.
# Predicted English :  I've seen this movie before.
# GLEU Score        :  0.17857142857142858
# 146
# Spanish           :  Si el tiempo es bueno, yo saldría mañana.
# Actual English    :  If the weather is good, I'll go out tomorrow.
# Predicted English :  If the weather is good, I'll go out tomorrow.
# GLEU Score        :  1.0
# 147
# Spanish           :  Levántame a las siete de la mañana.
# Actual English    :  Call me up at seven in the morning.
# Predicted English :  Wake me up at seven in the morning.
# GLEU Score        :  0.8
# 148
# Spanish           :  La verdad puede ser más dolorosa que la mentira.
# Actual English    :  The truth can be more painful than a lie.
# Predicted English :  The truth can be more painful than a lie.
# GLEU Score        :  1.0
# 149
# Spanish           :  Tengo que decir adiós.
# Actual English    :  I have to say goodbye.
# Predicted English :  I have to say goodbye.
# GLEU Score        :  1.0
# 150
# Spanish           :  ¡Cuidado! Las paredes tienen oídos.
# Actual English    :  Attention! The walls have ears.
# Predicted English :  Watch out! The walls have ears.
# GLEU Score        :  0.5833333333333334
# 151
# Spanish           :  La amistad es cuando alguien te dice siéntete como en casa y lo consigue inmediatamente.
# Actual English    :  Friendship is when someone tells you make yourself at home, and you immediately do.
# Predicted English :  Friendship is when someone tells you make yourself at home and you immediately achieve it.
# GLEU Score        :  0.45588235294117646
# 152
# Spanish           :  ¿Ha pasado algo interesante últimamente?
# Actual English    :  Has anything interesting happened recently?
# Predicted English :  Has anything interesting happened lately?
# GLEU Score        :  0.5238095238095238
# 153
# Spanish           :  Este enunciado no es una frase.
# Actual English    :  This statement is not a sentence.
# Predicted English :  This statement is not a sentence.
# GLEU Score        :  1.0
# 154
# Spanish           :  Tom y John son gemelos idénticos.
# Actual English    :  Tom and John are identical twins.
# Predicted English :  Tom and John are identical twins.
# GLEU Score        :  1.0
# 155
# Spanish           :  Este libro es para mí lo que la Biblia es para usted.
# Actual English    :  This book is to me what the Bible is to you.
# Predicted English :  This book is to me what the Bible is to you.
# GLEU Score        :  1.0
# 156
# Spanish           :  ¡Tómala! Es una bala mágica.
# Actual English    :  Take it! It's a magic bullet.
# Predicted English :  Take it! It's a magic bullet.
# GLEU Score        :  1.0
# 157
# Spanish           :  No hay nada mejor que los amigos de verdad.
# Actual English    :  Nothing beats real friends.
# Predicted English :  There's nothing better than real friends.
# GLEU Score        :  0.16666666666666666
# 158
# Spanish           :  Vos jugaste.
# Actual English    :  You played.
# Predicted English :  You played.
# GLEU Score        :  1.0
# 159
# Spanish           :  La toalla está en la tina.
# Actual English    :  The towel is in the tub.
# Predicted English :  The towel is in the tub.
# GLEU Score        :  1.0
# 160
# Spanish           :  Si la mujer se masturba, secretará hormonas femeninas y se volverá más femenina.
# Actual English    :  If a woman masturbates, she will secrete female hormones and become more feminine.
# Predicted English :  If a woman masturbates, she will secrete female hormones and become more feminine.
# GLEU Score        :  1.0
# 161
# Spanish           :  Dijo que me extrañaba.
# Actual English    :  He said he missed me.
# Predicted English :  He said he missed me.
# GLEU Score        :  1.0
# 162
# Spanish           :  Sé quiénes son todos ustedes.
# Actual English    :  I know who you all are.
# Predicted English :  I know who you all are.
# GLEU Score        :  1.0
# 163
# Spanish           :  Ellos partieron anoche.
# Actual English    :  They set out last night.
# Predicted English :  They set out last night.
# GLEU Score        :  1.0
# 164
# Spanish           :  Tomaste el móvil de la mesa.
# Actual English    :  You took the cellphone from the table.
# Predicted English :  You took the cellphone from the table.
# GLEU Score        :  1.0
# 165
# Spanish           :  La ventana estaba abierta de par en par.
# Actual English    :  The window was wide open.
# Predicted English :  The window was wide open.
# GLEU Score        :  1.0
# 166
# Spanish           :  He ahí la oferta.
# Actual English    :  That's the offer.
# Predicted English :  That's the offer.
# GLEU Score        :  1.0
# 167
# Spanish           :  Él está asando un pollo sabroso.
# Actual English    :  He's roasting a tasty chicken.
# Predicted English :  He is roasting a tasty chicken.
# GLEU Score        :  0.5714285714285714
# 168
# Spanish           :  Lo mataría si pudiera.
# Actual English    :  I'd kill you if I could.
# Predicted English :  I'd kill you if I could.
# GLEU Score        :  1.0
# 169
# Spanish           :  ¡Trata!
# Actual English    :  Try!
# Predicted English :  Try!
# GLEU Score        :  1.0
# 170
# Spanish           :  Lo harás por las buenas o por las malas.
# Actual English    :  You will do it whether you like it or not.
# Predicted English :  You'll do it whether you like it or not.
# GLEU Score        :  0.696969696969697
# 171
# Spanish           :  Me gusta jugar con las palabras.
# Actual English    :  I like to play with words.
# Predicted English :  I like playing with words.
# GLEU Score        :  0.32142857142857145
# 172
# Spanish           :  Enséñame cómo se hace, por favor.
# Actual English    :  Show me how to do it, please.
# Predicted English :  Show me how to do it, please.
# GLEU Score        :  1.0
# 173
# Spanish           :  No tengo ninguna canción preferida.
# Actual English    :  I don't have a favorite song.
# Predicted English :  I don't have a favorite song.
# GLEU Score        :  1.0
# 174
# Spanish           :  Yanni resultó estar loco.
# Actual English    :  Yanni turned out to be crazy.
# Predicted English :  Yanni turned out to be crazy.
# GLEU Score        :  1.0
# 175
# Spanish           :  En respuesta a tu solicitud, nosotros te ofrecemos un descuento extra del 5% en esta orden.
# Actual English    :  In reply to your request, we offer you an extra discount of 5% on this order.
# Predicted English :  In reply to your request, we offer you an extra discount of 5% on this order.
# GLEU Score        :  1.0
# 176
# Spanish           :  Él siempre cumple sus promesas.
# Actual English    :  He always fulfills his promises.
# Predicted English :  He always keeps his promises.
# GLEU Score        :  0.42857142857142855
# 177
# Spanish           :  ¿Sabe usted, cómo es de alta la torre de televisión?.
# Actual English    :  Do you know, how high is the television tower?.
# Predicted English :  Do you know, how high is the television tower?.
# GLEU Score        :  1.0
# 178
# Spanish           :  El cáncer puede ser curado con facilidad si es diagnosticado en la primera fase.
# Actual English    :  Cancer can be cured easily if it is found in its first phase.
# Predicted English :  Cancer can be cured easily if it is diagnosed in its first phase.
# GLEU Score        :  0.4857142857142857
# 179
# Spanish           :  Tom salió en televisión anoche.
# Actual English    :  Tom was on TV last night.
# Predicted English :  Tom was on TV last night.
# GLEU Score        :  1.0
# 180
# Spanish           :  John hizo levantarse a Mary.
# Actual English    :  John made Mary stand up.
# Predicted English :  John made Mary stand up.
# GLEU Score        :  1.0
# 181
# Spanish           :  Leyó la carta una y otra vez.
# Actual English    :  She read the letter over and over again.
# Predicted English :  He read the letter over and over again.
# GLEU Score        :  0.8
# 182
# Spanish           :  Todos mis hermanos son más altos que yo.
# Actual English    :  All my siblings are taller than me.
# Predicted English :  All of my brothers are taller than me.
# GLEU Score        :  0.37777777777777777
# 183
# Spanish           :  Esto parece más largo que eso, pero es una ilusión óptica.
# Actual English    :  This looks longer than that, but it is an optical illusion.
# Predicted English :  This looks longer than that, but it's an optical illusion.
# GLEU Score        :  0.5054945054945055
# 184
# Spanish           :  Tom le prestó su cámara a Mary.
# Actual English    :  Tom lent Mary his camera.
# Predicted English :  Tom lent his camera to Mary.
# GLEU Score        :  0.2857142857142857
# 185
# Spanish           :  La mayoría del tiempo resolvemos este problema de manera recursiva, pero la solución propuesta aquí ocupa un algoritmo iterativo.
# Actual English    :  We'd usually solve this problem recursively, but the proposed solution uses an iterative algorithm.
# Predicted English :  Let's solve this problem recursively most of the time, but the proposed solution uses an iterative algorithm.
# GLEU Score        :  0.30952380952380953
# 186
# Spanish           :  En ninguna parte de la Biblia está escrito que Jesús no era un velocirraptor.
# Actual English    :  Nowhere in the Bible does it state that Jesus wasn't a raptor.
# Predicted English :  Nowhere in the Bible does it state that Jesus was not a raptor.
# GLEU Score        :  0.580952380952381
# 187
# Spanish           :  Omite esta palabra.
# Actual English    :  Leave out this word.
# Predicted English :  Leave out this word.
# GLEU Score        :  1.0
# 188
# Spanish           :  ¿Cuándo es mi primer día de trabajo?
# Actual English    :  When is my first work day?
# Predicted English :  When's my first day at work?
# GLEU Score        :  0.19444444444444445
# 189
# Spanish           :  Él rara vez está en casa.
# Actual English    :  He is seldom home.
# Predicted English :  He is seldom at home.
# GLEU Score        :  0.42857142857142855
# 190
# Spanish           :  Yo veo tu casa.
# Actual English    :  I see your house.
# Predicted English :  I see your house.
# GLEU Score        :  1.0
# 191
# Spanish           :  ¿Puedes explicar tu respuesta?
# Actual English    :  Can you explain your answer?
# Predicted English :  Can you explain your answer?
# GLEU Score        :  1.0
# 192
# Spanish           :  La Navidad es un tiempo estupendo del año.
# Actual English    :  Christmas is a wonderful time of the year.
# Predicted English :  Christmas is a wonderful time of the year.
# GLEU Score        :  1.0
# 193
# Spanish           :  Envolvé la masa en una hoja de banano.
# Actual English    :  Wrap the pastry with a banana leaf.
# Predicted English :  Wrap the dough with a banana leaf.
# GLEU Score        :  0.5
# 194
# Spanish           :  La boda se celebró a las diez.
# Actual English    :  The wedding was celebrated at ten.
# Predicted English :  The wedding was celebrated at ten.
# GLEU Score        :  1.0
# 195
# Spanish           :  La ciudad Mako era el centro del cultivo de cebollas.
# Actual English    :  The city of Mako was a centre for the cultivation of onions.
# Predicted English :  The city of Mako was the centre for the cultivation of onions.
# GLEU Score        :  0.4725274725274725
# 196
# Spanish           :  Hablar inglés no es fácil, pero es interesante.
# Actual English    :  Speaking English isn't easy, but interesting.
# Predicted English :  Speaking English isn't easy, but it's interesting.
# GLEU Score        :  0.4696969696969697
# 197
# Spanish           :  Te haré un poco de café.
# Actual English    :  I'll make you some coffee.
# Predicted English :  I'll make you some coffee.
# GLEU Score        :  1.0
# 198
# Spanish           :  Hablas bien en inglés, ¿no es cierto?.
# Actual English    :  You can speak English well, can you not?.
# Predicted English :  You speak English well, don't you?.
# GLEU Score        :  0.22727272727272727
# 199
# Spanish           :  ¿La serpiente está viva o muerta?
# Actual English    :  Is the snake alive or dead?
# Predicted English :  Is the snake alive or dead?
# GLEU Score        :  1.0
# 200
# Spanish           :  ¿Quién mandó las flores?
# Actual English    :  Who sent the flowers?
# Predicted English :  Who sent the flowers?
# GLEU Score        :  1.0
# 201
# Spanish           :  Tom va a matar a Mary.
# Actual English    :  Tom is going to kill Mary.
# Predicted English :  Tom is going to kill Mary.
# GLEU Score        :  1.0
# 202
# Spanish           :  Tom le oculta sus preocupaciones a su esposa.
# Actual English    :  Tom hid his worries from his wife.
# Predicted English :  Tom hid his worries from his wife.
# GLEU Score        :  1.0
# 203
# Spanish           :  ¿Cuál es vuestro consejo?
# Actual English    :  What is your advice?
# Predicted English :  What's your advice?
# GLEU Score        :  0.4666666666666667
# 204
# Spanish           :  La venganza es dulce.
# Actual English    :  Revenge is sweet.
# Predicted English :  Revenge is sweet.
# GLEU Score        :  1.0
# 205
# Spanish           :  Se acerca el verano.
# Actual English    :  Summer is coming.
# Predicted English :  Summer is coming.
# GLEU Score        :  1.0
# 206
# Spanish           :  Me tengo que ir.
# Actual English    :  I have to leave.
# Predicted English :  I have to go.
# GLEU Score        :  0.4666666666666667
# 207
# Spanish           :  No me gusta llegar tarde.
# Actual English    :  I don't like being late.
# Predicted English :  I don't like being late.
# GLEU Score        :  1.0
# 208
# Spanish           :  Levanta tus manos.
# Actual English    :  Raise your hands.
# Predicted English :  Raise your hands.
# GLEU Score        :  1.0
# 209
# Spanish           :  El jardín es conocido por sus lirios.
# Actual English    :  The garden is famous for its irises.
# Predicted English :  The garden is famous for its irises.
# GLEU Score        :  1.0
# 210
# Spanish           :  Estos son mis principios, y si no te gustan. Bueno, tengo otros.
# Actual English    :  Those are my principles, and if you don't like them. well, I have others.
# Predicted English :  These are my principles, and if you don't like them. well, I have others.
# GLEU Score        :  0.9
# 211
# Spanish           :  Espero que duermas bien.
# Actual English    :  I hope you sleep well.
# Predicted English :  I hope you sleep well.
# GLEU Score        :  1.0
# 212
# Spanish           :  Él me miró a los ojos.
# Actual English    :  He looked me in the eye.
# Predicted English :  He looked me in the eye.
# GLEU Score        :  1.0
# 213
# Spanish           :  ¿Es cierto que el mundo se terminará el 2012?
# Actual English    :  Is it true that the world will end in 2012?
# Predicted English :  Is it true that the world will end in 2012?
# GLEU Score        :  1.0
# 214
# Spanish           :  Espera, hazlo así.
# Actual English    :  Try this instead.
# Predicted English :  Wait, do it this way.
# GLEU Score        :  0.07142857142857142
# 215
# Spanish           :  Ayer perdió mi equipo favorito.
# Actual English    :  My favorite team lost yesterday.
# Predicted English :  My favorite team lost yesterday.
# GLEU Score        :  1.0
# 216
# Spanish           :  Me vuelvo a casa, ya me he hartado de Tom.
# Actual English    :  I'm going home. I've had enough of Tom.
# Predicted English :  I'm going home. I've had enough of Tom.
# GLEU Score        :  1.0
# 217
# Spanish           :  El informe meteorológico dice que lloverá mañana por la tarde.
# Actual English    :  The weather report says it will rain tomorrow afternoon.
# Predicted English :  The weather report says it will rain tomorrow afternoon.
# GLEU Score        :  1.0
# 218
# Spanish           :  Esto es inaceptable.
# Actual English    :  This is unacceptable.
# Predicted English :  This is unacceptable.
# GLEU Score        :  1.0
# 219
# Spanish           :  Mary lleva puesto un vestido de plástico.
# Actual English    :  Mary is wearing a plastic dress.
# Predicted English :  Mary is wearing a plastic dress.
# GLEU Score        :  1.0
# 220
# Spanish           :  Ella se rodea de gente que piensa como ella.
# Actual English    :  She surrounds herself with like minded people.
# Predicted English :  She surrounds herself with people who think like her.
# GLEU Score        :  0.23636363636363636
# 221
# Spanish           :  No tenemos mucho tiempo.
# Actual English    :  We don't have too much time.
# Predicted English :  We don't have much time.
# GLEU Score        :  0.4444444444444444
# 222
# Spanish           :  Esa isla es territorio americano.
# Actual English    :  That island is American territory.
# Predicted English :  That island is American territory.
# GLEU Score        :  1.0
# 223
# Spanish           :  Está muy orgullosa de su hija.
# Actual English    :  She is very proud of her daughter.
# Predicted English :  She is very proud of her daughter.
# GLEU Score        :  1.0
# 224
# Spanish           :  En este momento él y sus hermanas viven en Tokio.
# Actual English    :  He and his sisters are currently living in Tokyo.
# Predicted English :  He and his sisters are currently living in Tokyo.
# GLEU Score        :  1.0
# 225
# Spanish           :  ¿Parezco estriptista?
# Actual English    :  Do I look like a stripper?
# Predicted English :  Do I look like a stripper?
# GLEU Score        :  1.0
# 226
# Spanish           :  Las clases empiezan el lunes.
# Actual English    :  Classes start on Monday.
# Predicted English :  Classes start on Monday.
# GLEU Score        :  1.0
# 227
# Spanish           :  Ella es inteligente y guapa.
# Actual English    :  She's beautiful and intelligent.
# Predicted English :  She's smart and beautiful.
# GLEU Score        :  0.2857142857142857
# 228
# Spanish           :  Si mezclás azul y rojo, el resultado es púrpura.
# Actual English    :  If you mix blue and red, the result is purple.
# Predicted English :  If you mix blue and red, the result is purple.
# GLEU Score        :  1.0
# 229
# Spanish           :  No soy vuestro amigo.
# Actual English    :  I'm not your friend.
# Predicted English :  I'm not your friend.
# GLEU Score        :  1.0
# 230
# Spanish           :  Un partido de Go comienza con un tablero vacío y las negras juegan primero a menos que jueguen con hándicap.
# Actual English    :  A game of Go starts with an empty board and Black plays first unless playing with a handicap.
# Predicted English :  A game of Go starts with an empty board and Black plays first unless playing with a handicap.
# GLEU Score        :  1.0
# 231
# Spanish           :  A ella le gusta correr.
# Actual English    :  She likes to run.
# Predicted English :  She likes to run.
# GLEU Score        :  1.0
# 232
# Spanish           :  El vietnamita es un idioma difícil pero hermoso.
# Actual English    :  Vietnamese is a difficult but beautiful language.
# Predicted English :  Vietnamese is a difficult but beautiful language.
# GLEU Score        :  1.0
# 233
# Spanish           :  A la hora en que llegó allí, el sol ya se había puesto.
# Actual English    :  By the time you got there, the sun had set.
# Predicted English :  By the time you got there, the sun had set.
# GLEU Score        :  1.0
# 234
# Spanish           :  Lo encontramos acá.
# Actual English    :  We found it here.
# Predicted English :  We found it here.
# GLEU Score        :  1.0
# 235
# Spanish           :  Si te pagan no estás haciendo caridad, simplemente estás haciendo tu trabajo.
# ...
# GLEU Score        :  1.0
# 422
# Spanish           :  Me gustaría ayudar.
# Actual English    :  I'd like to help.
# Predicted English :  I'd like to help.
# GLEU Score        :  1.0
# 423
# Spanish           :  No quiero hablar de ella.
# Actual English    :  I don't want to speak about her.
# Predicted English :  I don't want to talk about her.
# GLEU Score        :  0.4666666666666667
# 424
# Spanish           :  ¿A qué diario estás suscrito?
# Actual English    :  What newspaper do you subscribe to?
# Predicted English :  What newspaper do you subscribe to?
# GLEU Score        :  1.0
# 425
# Spanish           :  Un hombre a caballo vino por el camino.
# Actual English    :  A man on horseback came along the path.
# Predicted English :  A man on horseback came along the road.
# GLEU Score        :  0.6444444444444445
# 426
# Spanish           :  Esos albañiles no tienen cuidado, ya han caído varios cascotes por donde pasa la gente.
# Actual English    :  Those construction workers are not being careful already several pieces of rubble have fallen in the area where people are walking.
# Predicted English :  Those construction workers aren't careful. Several pieces of rubble have already fallen over where people are walking.
# GLEU Score        :  0.15019762845849802
# 427
# Spanish           :  Jane mandó a casa a Mary.
# Actual English    :  Jane sent Mary home.
# Predicted English :  Jane sent Mary home.
# GLEU Score        :  1.0
# 428
# Spanish           :  ¿Por qué tus ojos son tan grandes?
# Actual English    :  Why are your eyes so big?
# Predicted English :  Why are your eyes so big?
# GLEU Score        :  1.0
# 429
# Spanish           :  Yo creo en mis capacidades.
# Actual English    :  I believe in my abilities.
# Predicted English :  I believe in my abilities.
# GLEU Score        :  1.0
# 430
# Spanish           :  Tus ideas son bastante anticuadas.
# Actual English    :  Your ideas are rather old fashioned.
# Predicted English :  Your ideas are pretty old fashioned.
# GLEU Score        :  0.42857142857142855
# 431
# Spanish           :  Nuestras fuerzas ocuparon la ciudad.
# Actual English    :  Our forces occupied the city.
# Predicted English :  Our forces occupied the city.
# GLEU Score        :  1.0
# 432
# Spanish           :  Las personas menores de 18 años no se pueden casar.
# Actual English    :  People under 18 cannot get married.
# Predicted English :  People under 18 cannot get married.
# GLEU Score        :  1.0
# 433
# Spanish           :  No voy a la escuela.
# Actual English    :  I do not go to school.
# Predicted English :  I don't go to school.
# GLEU Score        :  0.4642857142857143
# 434
# Spanish           :  ¿Deberíamos seguir?
# Actual English    :  Should we continue?
# Predicted English :  Should we continue?
# GLEU Score        :  1.0
# 435
# Spanish           :  Tom tiene buen oído.
# Actual English    :  Tom has good hearing.
# Predicted English :  Tom has good hearing.
# GLEU Score        :  1.0
# 436
# Spanish           :  No hace falta apresurarse. Tenemos un montón de tiempo.
# Actual English    :  There's no need to hurry. We have plenty of time.
# Predicted English :  There's no need to hurry. We have plenty of time.
# GLEU Score        :  1.0
# 437
# Spanish           :  Él pinta paisajes frecuentemente.
# Actual English    :  He often paints landscapes.
# Predicted English :  He often paints landscapes.
# GLEU Score        :  1.0
# 438
# Spanish           :  ¿Por qué aprendían alemán?
# Actual English    :  Why did you learn German?
# Predicted English :  Why did you learn German?
# GLEU Score        :  1.0
# 439
# Spanish           :  No sonó el despertador y me quedé dormido.
# Actual English    :  The alarm didn't go off and I kept sleeping.
# Predicted English :  The alarm didn't go off and I fell asleep.
# GLEU Score        :  0.5606060606060606
# 440
# Spanish           :  Escucha atentamente.
# Actual English    :  Listen well.
# Predicted English :  Listen carefully.
# GLEU Score        :  0.3333333333333333
# 441
# Spanish           :  ¿Y contigo?
# Actual English    :  How about with you?
# Predicted English :  What about you?
# GLEU Score        :  0.26666666666666666
# 442
# Spanish           :  Tom está agregando frases a Tatoeba.
# Actual English    :  Tom is adding sentences to Tatoeba.
# Predicted English :  Tom is adding sentences to Tatoeba.
# GLEU Score        :  1.0
# 443
# Spanish           :  Tom está volviendo en sí.
# Actual English    :  Tom is coming to.
# Predicted English :  Tom is coming to.
# GLEU Score        :  1.0
# 444
# Spanish           :  Están ambos en la habitación.
# Actual English    :  The two of them are in the room.
# Predicted English :  Both of them are in the room.
# GLEU Score        :  0.6222222222222222
# 445
# Spanish           :  Quiero que te vayas ahora mismo.
# Actual English    :  I want you to leave right now.
# Predicted English :  I want you to leave right now.
# GLEU Score        :  1.0
# 446
# Spanish           :  Ella me escribe cada semana.
# Actual English    :  She writes me every week.
# Predicted English :  She writes to me every week.
# GLEU Score        :  0.4642857142857143
# 447
# Spanish           :  Por favor, mueve esta piedra de aquí a allí.
# Actual English    :  Please move this stone from here to there.
# Predicted English :  Please move this stone from here to there.
# GLEU Score        :  1.0
# 448
# Spanish           :  ¿Por qué tiene la boca tan grande?
# Actual English    :  Why is your mouth so big?
# Predicted English :  Why is his mouth so big?
# GLEU Score        :  0.4642857142857143
# 449
# Spanish           :  Puedes comer cuanto quieras.
# Actual English    :  You can eat as much as you want.
# Predicted English :  You can eat as much as you want.
# GLEU Score        :  1.0
# 450
# Spanish           :  Él está escribiendo una novela nueva.
# Actual English    :  He's writing a new novel.
# Predicted English :  He's writing a new novel.
# GLEU Score        :  1.0
# 451
# Spanish           :  Tom está silbando.
# Actual English    :  Tom is whistling.
# Predicted English :  Tom is whistling.
# GLEU Score        :  1.0
# 452
# Spanish           :  La ciudad abandonada fue tragada por la selva.
# Actual English    :  The abandoned city was swallowed by the jungle.
# Predicted English :  The abandoned city was swallowed up by the jungle.
# GLEU Score        :  0.45454545454545453
# 453
# Spanish           :  Tiene varios compradores para la finca.
# Actual English    :  He has several buyers for the property.
# Predicted English :  He has several buyers for the property.
# GLEU Score        :  1.0
# 454
# Spanish           :  Muchas gracias por su obsequio.
# Actual English    :  Thank you very much for your gift.
# Predicted English :  Thank you very much for your present.
# GLEU Score        :  0.6111111111111112
# 455
# Spanish           :  Tom tuvo una experiencia traumática.
# Actual English    :  Tom had a traumatic experience.
# Predicted English :  Tom had a traumatic experience.
# GLEU Score        :  1.0
# 456
# Spanish           :  María se puso sus joyas.
# Actual English    :  Mary put her jewellery on.
# Predicted English :  Mary put her jewels on.
# GLEU Score        :  0.42857142857142855
# 457
# Spanish           :  Nadie tenía linterna.
# Actual English    :  No one had a flashlight.
# Predicted English :  No one had a flashlight.
# GLEU Score        :  1.0
# 458
# Spanish           :  John está seguro, el aire fresco es una cosa buena.
# Actual English    :  John is sure that fresh air is a good thing.
# Predicted English :  John is sure that fresh air is a good thing.
# GLEU Score        :  1.0
# 459
# Spanish           :  Debido a problemas técnicos, pusieron una película en vez del programa anunciado.
# Actual English    :  Because of some technical problem, a movie was shown in place of the announced program.
# Predicted English :  Due to technical problems, a movie was shown in place of the announced program.
# GLEU Score        :  0.5163398692810458
# 460
# Spanish           :  Tom no conoce los detalles.
# Actual English    :  Tom doesn't know the details.
# Predicted English :  Tom doesn't know the details.
# GLEU Score        :  1.0
# 461
# Spanish           :  ¿Quieres salvarlos?
# Actual English    :  Do you want to save them?
# Predicted English :  Do you want to save them?
# GLEU Score        :  1.0
# 462
# Spanish           :  Le consideran un héroe.
# Actual English    :  They consider him a hero.
# Predicted English :  They regard him as a hero.
# GLEU Score        :  0.2857142857142857
# 463
# Spanish           :  ¿Hay una tienda en este zoológico?
# Actual English    :  Is there a shop at this zoo?
# Predicted English :  Is there a shop at this zoo?
# GLEU Score        :  1.0
# 464
# Spanish           :  Él conduce un camión.
# Actual English    :  He drives a truck.
# Predicted English :  He drives a truck.
# GLEU Score        :  1.0
# 465
# Spanish           :  Tom tiene menos amigos que yo.
# Actual English    :  Tom has fewer friends than I do.
# Predicted English :  Tom has fewer friends than I do.
# GLEU Score        :  1.0
# 466
# Spanish           :  Algunas personas están leyendo revistas en el tren.
# Actual English    :  Some people are reading some magazines on the train.
# Predicted English :  Some people are reading magazines on the train.
# GLEU Score        :  0.45454545454545453
# 467
# Spanish           :  La mujeres romanas dilataban sus pupilas con belladona porque creían que esto las hacía más atractivas. Los oculistas aún usan la belladona durante sus exámenes oculares.
# Actual English    :  Roman women would dilate their pupils with belladonna because they believed this made them more attractive. Eye doctors still use belladonna during eye exams.
# Predicted English :  Roman women would dilate their pupils with belladonna because they believed this made them more attractive. Eye doctors still use belladonna during eye exams.
# GLEU Score        :  1.0
# 468
# Spanish           :  Necesito un nuevo ordenador.
# Actual English    :  I need a new computer.
# Predicted English :  I need a new computer.
# GLEU Score        :  1.0
# 469
# Spanish           :  No me abandones.
# Actual English    :  Don't abandon me.
# Predicted English :  Don't abandon me.
# GLEU Score        :  1.0
# 470
# Spanish           :  Ella no visitó a nadie.
# Actual English    :  She didn't visit anybody.
# Predicted English :  She didn't visit anyone.
# GLEU Score        :  0.5238095238095238
# 471
# Spanish           :  ¿Sabes hablar francés?
# Actual English    :  Do you speak French?
# Predicted English :  Can you speak French?
# GLEU Score        :  0.6666666666666666
# 472
# Spanish           :  Tomás no tiene hambre.
# Actual English    :  Tom isn't hungry.
# Predicted English :  Tom isn't hungry.
# GLEU Score        :  1.0
# 473
# Spanish           :  Hay que cumplir las reglas.
# Actual English    :  One must observe the rules.
# Predicted English :  You have to abide by the rules.
# GLEU Score        :  0.16666666666666666
# 474
# Spanish           :  Ella corrió tan rápido como pudo para alcanzar a los demás.
# Actual English    :  She ran as fast as she could to catch up with the others.
# Predicted English :  She ran as fast as she could to catch up with the others.
# GLEU Score        :  1.0
# 475
# Spanish           :  ¿Dónde está tu campera?
# Actual English    :  Where's your jacket?
# Predicted English :  Where's your jacket?
# GLEU Score        :  1.0
# 476
# Spanish           :  Eso es lo que debí haber dicho.
# Actual English    :  That's what I should've said.
# Predicted English :  That's what I should've said.
# GLEU Score        :  1.0
# 477
# Spanish           :  Los científicos todavía no han hallado la cura contra el cáncer.
# Actual English    :  Scientists haven't found a cure for cancer yet.
# Predicted English :  Scientists haven't found a cure for cancer yet.
# GLEU Score        :  1.0
# 478
# Spanish           :  ¿Han conectado la antena del radio?
# Actual English    :  Have they connected the radio antenna?
# Predicted English :  Have they connected the radio antenna?
# GLEU Score        :  1.0
# 479
# Spanish           :  Los antibióticos suelen ser inhibidores enzimáticos.
# Actual English    :  Antibiotics are commonly enzymatic inhibitors.
# Predicted English :  Antibiotics are commonly enzymatic inhibitors.
# GLEU Score        :  1.0
# 480
# Spanish           :  Esta sombra de ojos me queda espectacular, ¿verdad?.
# Actual English    :  This eyeshadow looks spectacular on me, doesn't it?.
# Predicted English :  This eyeshadow looks spectacular on me, doesn't it?.
# GLEU Score        :  1.0
# 481
# Spanish           :  Pensé que Tom hizo esto.
# Actual English    :  I thought Tom did this.
# Predicted English :  I thought Tom did this.
# GLEU Score        :  1.0
# 482
# Spanish           :  Ella echa mucho azúcar en el café.
# Actual English    :  She puts a lot of sugar in her coffee.
# Predicted English :  She puts a lot of sugar in her coffee.
# GLEU Score        :  1.0
# 483
# Spanish           :  Eso pasó hace realmente mucho tiempo.
# Actual English    :  That was a really long time ago.
# Predicted English :  That was a really long time ago.
# GLEU Score        :  1.0
# 484
# Spanish           :  Tú eres culpable de asesinato.
# Actual English    :  You are guilty of murder.
# Predicted English :  You're guilty of murder.
# GLEU Score        :  0.5238095238095238
# 485
# Spanish           :  Le doy un ramo de flores a mi amiga.
# Actual English    :  I give my friend a bunch of flowers.
# Predicted English :  I give my friend a bunch of flowers.
# GLEU Score        :  1.0
# 486
# Spanish           :  Hua Luogeng es matemático.
# Actual English    :  Hua Luogeng is a mathematician.
# Predicted English :  Hua Luogeng is a mathematician.
# GLEU Score        :  1.0
# 487
# Spanish           :  Aquí está mi billete de vuelta.
# Actual English    :  Here's my return ticket.
# Predicted English :  Here's my return ticket.
# GLEU Score        :  1.0
# 488
# Spanish           :  Esta novela en inglés no es tan sencilla como para que la leas en una semana.
# Actual English    :  This English novel is not easy enough for you to read in a week.
# Predicted English :  This English novel isn't easy enough for you to read in a week.
# GLEU Score        :  0.5416666666666666
# 489
# Spanish           :  El otro día visité el museo.
# Actual English    :  The other day I visited the museum.
# Predicted English :  I visited the museum the other day.
# GLEU Score        :  0.3888888888888889
# 490
# Spanish           :  Yo no bebo café.
# Actual English    :  I don't drink coffee.
# Predicted English :  I don't drink coffee.
# GLEU Score        :  1.0
# 491
# Spanish           :  Yo dormí bastante.
# Actual English    :  I slept a lot.
# Predicted English :  I slept a lot.
# GLEU Score        :  1.0
# 492
# Spanish           :  En el amplio sentido, el hombre también es un animal.
# Actual English    :  Man is also an animal in a broad sense.
# Predicted English :  Man is also an animal in a broad sense.
# GLEU Score        :  1.0
# 493
# Spanish           :  Mejor solo que con tontos.
# Actual English    :  Much better alone than with fools.
# Predicted English :  Better alone than with fools.
# GLEU Score        :  0.5357142857142857
# 494
# Spanish           :  Algo surgió.
# Actual English    :  Something came up.
# Predicted English :  Something has come up.
# GLEU Score        :  0.26666666666666666
# 495
# Spanish           :  A Tom no le gusta la manera en que Mary se ríe.
# Actual English    :  Tom doesn't like the way Mary laughs.
# Predicted English :  Tom doesn't like the way Mary laughs.
# GLEU Score        :  1.0
# 496
# Spanish           :  ¿Dónde está mi abrigo?
# Actual English    :  Where's my coat?
# Predicted English :  Where's my coat?
# GLEU Score        :  1.0
# 497
# Spanish           :  ¿Qué bebidas no te gustan?
# Actual English    :  Which drinks don't you like?
# Predicted English :  Which drinks don't you like?
# GLEU Score        :  1.0
# 498
# Spanish           :  Yo que usted no entraba.
# Actual English    :  I wouldn't go in if I were you.
# Predicted English :  If I were you, I wouldn't come in.
# GLEU Score        :  0.21212121212121213
# 499
# Spanish           :  Hasta mi mamá sabe.
# Actual English    :  Even my mom knows.
# Predicted English :  Even my mom knows.
# GLEU Score        :  1.0
# 500
# Spanish           :  Le aconsejó que tomara un descanso.
# Actual English    :  She advised him to take a rest.
# Predicted English :  She advised him to take a rest.
# GLEU Score        :  1.0
# 277.0463354587555

# %%
avg_scores_gleu = Average(scos)

# %%
avg_scores_gleu
# Out:
# 0.7970957304261775

# %% [markdown]
# # **Model Testing Section**
#
# ✅✅***Standalone section in terms of testing the english-spanish model.***✅✅

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# need to run the below cell to train or test the model ***(both locally and for huggingface)***

# %%
# !pip install datasets
# !pip install sacremoses
# !pip install transformers
# !pip install huggingface_hub
# !pip install transformers[sentencepiece] datasets

# %% [markdown]
# need to run the below cell to train or test the model ***(only for huggingface)***

# %%
from huggingface_hub import notebook_login

notebook_login()
# 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          ------------------(use this token in the box below)-------------------

# %% [markdown]
# need to run the below cell to train or test the model ***(only for huggingface)***

# %%
# !apt install git-lfs
# !git config --global user.email "shamimmahbub230@gmail.com"
# !git config --global user.name "shamim237"

# %% [markdown]
# run the below cell to load the model for testing ***(only for huggingface)***

# %%
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM


model_name = 'shamim237/es-en-model'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = TFAutoModelForSeq2SeqLM.from_pretrained(model_name)

# %% [markdown]
# run the below cell to load the model for testing ***(only for locally)***

# %%
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM

# load the saved model and tokenizer from local drive

tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/Language-Translation/es-en/misc")
model = TFAutoModelForSeq2SeqLM.from_pretrained("/content/drive/MyDrive/Language-Translation/es-en/misc")

# %% [markdown]
# **run all the cells in the below**, to test the model in training and testing dataset **(both locally and for huggingface)**

# %%
import time
import nltk
import pandas as pd
import tensorflow as tf
from collections import Counter
from nltk.util import everygrams, ngrams
nltk.download('punkt')

# %%
@tf.function(jit_compile=True)
def generate(inputs):
    return model.generate(**inputs, max_length=128)


# function to get the GLEU Score
  
def sentence_gleu(references, hypothesis, min_len=1, max_len=4):
    return corpus_gleu([references], [hypothesis], min_len=min_len, max_len=max_len)


def corpus_gleu(list_of_references, hypotheses, min_len=1, max_len=4):

    # sanity check
    assert len(list_of_references) == len(
        hypotheses
    ), "The number of hypotheses and their reference(s) should be the same"

    # sum matches and max-token-lengths over all sentences
    corpus_n_match = 0
    corpus_n_all = 0

    for references, hypothesis in zip(list_of_references, hypotheses):
        hyp_ngrams = Counter(everygrams(hypothesis, min_len, max_len))
        tpfp = sum(hyp_ngrams.values())  # True positives + False positives.

        hyp_counts = []
        for reference in references:
            ref_ngrams = Counter(everygrams(reference, min_len, max_len))
            # True positives + False negatives.
            tpfn = sum(ref_ngrams.values())

            overlap_ngrams = ref_ngrams & hyp_ngrams
            tp = sum(overlap_ngrams.values())  # True positives.
            n_all = max(tpfp, tpfn)

            if n_all > 0:
                hyp_counts.append((tp, n_all))

        # use the reference yielding the highest score
        if hyp_counts:
            n_match, n_all = max(hyp_counts, key=lambda hc: hc[0] / hc[1])
            corpus_n_match += n_match
            corpus_n_all += n_all

    # corner case: empty corpus or empty references---don't divide by zero!
    if corpus_n_all == 0:
        gleu_score = 0.0
    else:
        gleu_score = corpus_n_match / corpus_n_all

    return gleu_score


#  to get average of GLEU Score on test dataset
def Average(lst):
    sum_of_list = 0
    for i in range(len(lst)):
        sum_of_list += lst[i]
    average = sum_of_list/len(lst)
    return average

# %% [markdown]
# get individual GLEU score on test dataset

# %%
test_data = pd.read_csv("/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en-test.csv")

# %%
start_time = time.time()
sco = []
k = 0
for eng, spa in zip(test_data['spanish'], test_data['english']):
  k +=1
  print(k)
  print("Spanish           : ", eng)
  print("Actual English    : ", spa)
  tokenized_data = tokenizer([eng], return_tensors="np", pad_to_multiple_of=128)
  #print(tokenized_data)
  out = generate(tokenized_data)
  with tokenizer.as_target_tokenizer():
    print("Predicted English : ", tokenizer.decode(out[0], skip_special_tokens=True))
    actual_spanish    = nltk.word_tokenize(spa)
    predicted_spanish = nltk.word_tokenize(tokenizer.decode(out[0], skip_special_tokens=True)) 
    scores = corpus_gleu([[actual_spanish]], [predicted_spanish], min_len=1, max_len=128)
    print("GLEU Score        : ", scores)
    sco.append(scores)
    if k ==500: ################## change this value based on the samples you want to get the GLEU scores for
      now = time.time()
      t_time = now-start_time
      print(t_time)
      break

# %%
avg_scores_gleu = Average(sco)

# %%
avg_scores_gleu # average gleu score for test dataset

# %% [markdown]
# get individual GLEU score on train dataset

# %%
train_data = pd.read_csv("/content/drive/MyDrive/Language-Translation/es-en/dataset/es-en-train.csv")

# %%
start_time = time.time()
sco = []
k = 0
for eng, spa in zip(test_data['spanish'], test_data['english']):
  k +=1
  print(k)
  print("Spanish           : ", eng)
  print("Actual English    : ", spa)
  tokenized_data = tokenizer([eng], return_tensors="np", pad_to_multiple_of=128)
  #print(tokenized_data)
  out = generate(tokenized_data)
  with tokenizer.as_target_tokenizer():
    print("Predicted English : ", tokenizer.decode(out[0], skip_special_tokens=True))
    actual_spanish    = nltk.word_tokenize(spa)
    predicted_spanish = nltk.word_tokenize(tokenizer.decode(out[0], skip_special_tokens=True)) 
    scores = corpus_gleu([[actual_spanish]], [predicted_spanish], min_len=1, max_len=128)
    print("GLEU Score        : ", scores)
    sco.append(scores)
    if k ==500: ################## change this value based on the samples you want to get the GLEU scores for
      now = time.time()
      t_time = now-start_time
      print(t_time)
      break

# %%
avg_scores_gleu = Average(sco)

# %%
avg_scores_gleu # average gleu score for training dataset
